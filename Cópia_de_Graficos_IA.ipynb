# %% [markdown]
# <a href="https://colab.research.google.com/github/kingofrats04/Projeto_IA_DadosEnem/blob/main/C%C3%B3pia_de_Graficos_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Análise exploratória de dados

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import seaborn as sns
import string

# Importando planilha do Excel
planilha2020 = pd.read_csv("./drive/MyDrive/trabalho_ia/data/MICRODADOS_ENEM_2020_DF.csv", sep=';' , encoding='latin-1')
planilha2021 = pd.read_csv("./drive/MyDrive/trabalho_ia/data/MICRODADOS_ENEM_2021_DF.csv", sep=';' , encoding='latin-1')

#---------------------------------- Grafico 1 - Total alunos por ano ----------------------------------

# Printar total de participantes por ano
print('Numero total de participantes na planilha Microdados Enem 2020:', planilha2020.NU_PARTICIPANTES.max())
print('Numero total de participantes na planilha Microdados Enem 2021:', planilha2021.NU_PARTICIPANTES.max(), '\n')

NU_PARTICIPANTES_2020 = planilha2020.NU_PARTICIPANTES.max()
NU_PARTICIPANTES_2021 = planilha2021.NU_PARTICIPANTES.max()

# Printando grafico de barras horizontal
x = ['Planilha 2020', 'Planilha 2021']
y = [NU_PARTICIPANTES_2020, NU_PARTICIPANTES_2021]

total_NU_PARTICIPANTES_2020_2021 = NU_PARTICIPANTES_2020, NU_PARTICIPANTES_2021
plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.rcParams['figure.figsize'] = [5, 5]

plt.barh(x, total_NU_PARTICIPANTES_2020_2021, align='center', color=['blue', 'red'], edgecolor='black', linewidth="1") 
plt.xlabel("Total alunos por ano")
plt.ylabel("Planilhas")
# Out:
# Numero total de participantes na planilha Microdados Enem 2020: 116932
# Numero total de participantes na planilha Microdados Enem 2021: 67501
# Text(0, 0.5, 'Planilhas')

# %%
# Histograma projetando o total de participante dos dois anos
print(planilha2020.NU_PARTICIPANTES.hist())
print(planilha2021.NU_PARTICIPANTES.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 2 - Participantes por sexo ----------------------------------

#display(planilha2020.loc[(planilha2020['TP_SEXO']=='F')])
#display(planilha2020.loc[(planilha2020['TP_SEXO']=='M')])
#display(planilha2021.loc[(planilha2021['TP_SEXO']=='F')])
#display(planilha2021.loc[(planilha2021['TP_SEXO']=='M')])

TP_SEXO_F_2020 = 70044 
TP_SEXO_M_2020 = 46888

TP_SEXO_F_2021 = 41167
TP_SEXO_M_2021 = 26334

# Printar total de participantes por sexo
print('Numero total de participantes do sexo feminino na planilha Microdados Enem 2020:', TP_SEXO_F_2020)
print('Numero total de participantes do sexo masculino planilha Microdados Enem 2020:', TP_SEXO_M_2020, '\n')
print('Numero total de participantes do sexo feminino planilha Microdados Enem 2021:', TP_SEXO_F_2021)
print('Numero total de participantes do sexo masculino planilha Microdados Enem 2021:', TP_SEXO_M_2021, '\n')

# Printando grafico de barras horizontal
x = ['Feminino 2020', 'Masculino 2020', 'Feminino 2021', 'Masculino 2021']
y = [TP_SEXO_F_2020, TP_SEXO_M_2020, TP_SEXO_F_2021, TP_SEXO_M_2021]

total_TP_SEXO_FM_2020_2021 = TP_SEXO_F_2020, TP_SEXO_M_2020, TP_SEXO_F_2021, TP_SEXO_M_2021
plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_TP_SEXO_FM_2020_2021, align='center', color=['blue', 'blue', 'red', 'red'], edgecolor='black', linewidth="1") 
plt.xlabel("Total participantes no ano")
plt.ylabel("Participantes por sexo")
# Out:
# Numero total de participantes do sexo feminino na planilha Microdados Enem 2020: 70044
# Numero total de participantes do sexo masculino planilha Microdados Enem 2020: 46888
#
# Numero total de participantes do sexo feminino planilha Microdados Enem 2021: 41167
# Numero total de participantes do sexo masculino planilha Microdados Enem 2021: 26334
# Text(0, 0.5, 'Participantes por sexo')

# %%
# Histograma projetando a quatidade de participantes por sexo nos dos dois anos
print(planilha2020.TP_SEXO.hist())
print(planilha2021.TP_SEXO.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 3 - Estado civil por ano ----------------------------------

#display(planilha2020.loc[(planilha2020['TP_ESTADO_CIVIL']==0)])
#display(planilha2020.loc[(planilha2020['TP_ESTADO_CIVIL']==1)])
#display(planilha2020.loc[(planilha2020['TP_ESTADO_CIVIL']==2)])
#display(planilha2020.loc[(planilha2020['TP_ESTADO_CIVIL']==3)])
#display(planilha2020.loc[(planilha2020['TP_ESTADO_CIVIL']==4)])

#display(planilha2021.loc[(planilha2021['TP_ESTADO_CIVIL']==0)])
#display(planilha2021.loc[(planilha2021['TP_ESTADO_CIVIL']==1)])
#display(planilha2021.loc[(planilha2021['TP_ESTADO_CIVIL']==2)])
#display(planilha2021.loc[(planilha2021['TP_ESTADO_CIVIL']==3)])
#display(planilha2021.loc[(planilha2021['TP_ESTADO_CIVIL']==4)])

TP_ESTADO_CIVIL_0_2020 = 2735
TP_ESTADO_CIVIL_1_2020 = 96223
TP_ESTADO_CIVIL_2_2020 = 11851
TP_ESTADO_CIVIL_3_2020 = 3353
TP_ESTADO_CIVIL_4_2020 = 170

TP_ESTADO_CIVIL_0_2021 = 5335
TP_ESTADO_CIVIL_1_2021 = 58726 
TP_ESTADO_CIVIL_2_2021 = 4604
TP_ESTADO_CIVIL_3_2021 = 1353
TP_ESTADO_CIVIL_4_2021 = 83 

# Printar total de participantes por sexo
print('Numero total de participantes com estado civil 0 (não informado) na planilha Microdados Enem 2020:', TP_ESTADO_CIVIL_0_2020)
print('Numero total de participantes com estado civil 1 (solteiro(a)) na planilha Microdados Enem 2020:', TP_ESTADO_CIVIL_1_2020)
print('Numero total de participantes com estado civil 2 (casado(a)/mora com companheiro(a)) na planilha Microdados Enem 2020:', TP_ESTADO_CIVIL_2_2020)
print('Numero total de participantes com estado civil 3 (divorciado(a)/desquitado(a)/separado(a)) na planilha Microdados Enem 2020:', TP_ESTADO_CIVIL_3_2020)
print('Numero total de participantes com estado civil 4 (viúvo(a)) na planilha Microdados Enem 2020:', TP_ESTADO_CIVIL_4_2020,'\n')

print('Numero total de participantes com estado civil 0 (não informado) na planilha Microdados Enem 2021:', TP_ESTADO_CIVIL_0_2021)
print('Numero total de participantes com estado civil 1 (solteiro(a)) na planilha Microdados Enem 2021:', TP_ESTADO_CIVIL_1_2021)
print('Numero total de participantes com estado civil 2 (casado(a)/mora com companheiro(a)) na planilha Microdados Enem 2021:', TP_ESTADO_CIVIL_2_2021)
print('Numero total de participantes com estado civil 3 (divorciado(a)/desquitado(a)/separado(a)) na planilha Microdados Enem 2021:', TP_ESTADO_CIVIL_3_2021)
print('Numero total de participantes com estado civil 4 (viúvo(a)) na planilha Microdados Enem 2021:', TP_ESTADO_CIVIL_4_2021,'\n')

# Printando grafico de barras horizontal
x = ['Não informado 2020', 'Solteiro 2020', 'Casado/União estável 2020', 'Divorciado 2020', 'Viúvo 2020', 'Não informado 2021', 'Solteiro 2021', 'Casado/União estável 2021', 'Divorciado 2021', 'Viúvo 2021']
y = [TP_ESTADO_CIVIL_0_2020, TP_ESTADO_CIVIL_1_2020, TP_ESTADO_CIVIL_2_2020, TP_ESTADO_CIVIL_3_2020, TP_ESTADO_CIVIL_4_2020, TP_ESTADO_CIVIL_0_2021, TP_ESTADO_CIVIL_1_2021, TP_ESTADO_CIVIL_2_2021, TP_ESTADO_CIVIL_3_2021, TP_ESTADO_CIVIL_4_2021]

total_Estado_Civil_2020_2021 = TP_ESTADO_CIVIL_0_2020, TP_ESTADO_CIVIL_1_2020, TP_ESTADO_CIVIL_2_2020, TP_ESTADO_CIVIL_3_2020, TP_ESTADO_CIVIL_4_2020, TP_ESTADO_CIVIL_0_2021, TP_ESTADO_CIVIL_1_2021, TP_ESTADO_CIVIL_2_2021, TP_ESTADO_CIVIL_3_2021, TP_ESTADO_CIVIL_4_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_Estado_Civil_2020_2021, align='center', color=['blue', 'blue', 'blue', 'blue', 'blue', 'red', 'red', 'red', 'red', 'red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por estado civil")
plt.ylabel("Estado civil por ano")
# Out:
# Numero total de participantes com estado civil 0 (não informado) na planilha Microdados Enem 2020: 2735
# Numero total de participantes com estado civil 1 (solteiro(a)) na planilha Microdados Enem 2020: 96223
# Numero total de participantes com estado civil 2 (casado(a)/mora com companheiro(a)) na planilha Microdados Enem 2020: 11851
# Numero total de participantes com estado civil 3 (divorciado(a)/desquitado(a)/separado(a)) na planilha Microdados Enem 2020: 3353
# Numero total de participantes com estado civil 4 (viúvo(a)) na planilha Microdados Enem 2020: 170
#
# Numero total de participantes com estado civil 0 (não informado) na planilha Microdados Enem 2021: 5335
# Numero total de participantes com estado civil 1 (solteiro(a)) na planilha Microdados Enem 2021: 58726
# Numero total de participantes com estado civil 2 (casado(a)/mora com companheiro(a)) na planilha Microdados Enem 2021: 4604
# ...

# %%
# Histograma projetando a quatidade de participantes por estado civil nos dos dois anos
print(planilha2020.TP_ESTADO_CIVIL.hist())
print(planilha2021.TP_ESTADO_CIVIL.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 4 - Faixa etaria por ano 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 1)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 2)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 3)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 4)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 5)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 6)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 7)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 8)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 9)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 10)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 11)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 12)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 13)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 14)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 15)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 16)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 17)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 18)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 19)])
#display(planilha2021.loc[(planilha2021['TP_FAIXA_ETARIA'] == 20)])

TP_FAIXA_ETARIA_1_2021 = 4200
TP_FAIXA_ETARIA_2_2021 = 11126
TP_FAIXA_ETARIA_3_2021 = 14066
TP_FAIXA_ETARIA_4_2021 = 8034
TP_FAIXA_ETARIA_5_2021 = 4890
TP_FAIXA_ETARIA_6_2021 = 3509
TP_FAIXA_ETARIA_7_2021 = 2674
TP_FAIXA_ETARIA_8_2021 = 2164
TP_FAIXA_ETARIA_9_2021 = 1822
TP_FAIXA_ETARIA_10_2021 = 1494
TP_FAIXA_ETARIA_11_2021 = 4868
TP_FAIXA_ETARIA_12_2021 = 2890
TP_FAIXA_ETARIA_13_2021 = 2181
TP_FAIXA_ETARIA_14_2021 = 3583

print('Numero total de participantes com faixa etária 1 (menor de 17 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_1_2021)
print('Numero total de participantes com faixa etária 2 (17 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_2_2021)
print('Numero total de participantes com faixa etária 3 (18 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_3_2021)
print('Numero total de participantes com faixa etária 4 (19 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_4_2021)
print('Numero total de participantes com faixa etária 5 (20 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_5_2021)
print('Numero total de participantes com faixa etária 6 (21 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_6_2021)
print('Numero total de participantes com faixa etária 7 (22 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_7_2021)
print('Numero total de participantes com faixa etária 8 (23 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_8_2021)
print('Numero total de participantes com faixa etária 9 (24 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_9_2021)
print('Numero total de participantes com faixa etária 10 (25 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_10_2021)
print('Numero total de participantes com faixa etária 11 (entre 26 e 30 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_11_2021)
print('Numero total de participantes com faixa etária 12 (entre 31 e 35 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_12_2021)
print('Numero total de participantes com faixa etária 13 (entre 36 e 40 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_13_2021)
print('Numero total de participantes com faixa etária 14 (maiores de 41 anos) na planilha Microdados Enem 2021:', TP_FAIXA_ETARIA_14_2021, '\n')

# Printando grafico de barras horizontal
x = ['Menor de 17 anos 2021', '17 anos 2021', '18 anos 2021', '19 anos 2021', '20 anos 2021', '21 anos 2021', '22 anos 2021', '23 anos 2021', '24 anos 2021', '25 anos 2021', 'Entre 26 e 30 anos 2021', 'Entre 31 e 35 anos 2021', 'Entre 36 e 40 anos 2021', 'Maiores de 41 anos 2021']
y = [TP_FAIXA_ETARIA_1_2021, TP_FAIXA_ETARIA_2_2021, TP_FAIXA_ETARIA_3_2021, TP_FAIXA_ETARIA_4_2021, TP_FAIXA_ETARIA_5_2021, TP_FAIXA_ETARIA_6_2021, TP_FAIXA_ETARIA_7_2021, TP_FAIXA_ETARIA_8_2021, TP_FAIXA_ETARIA_9_2021, TP_FAIXA_ETARIA_10_2021, TP_FAIXA_ETARIA_11_2021, TP_FAIXA_ETARIA_12_2021, TP_FAIXA_ETARIA_13_2021, TP_FAIXA_ETARIA_14_2021]

total_Faixa_Etaria_2021 = TP_FAIXA_ETARIA_1_2021, TP_FAIXA_ETARIA_2_2021, TP_FAIXA_ETARIA_3_2021, TP_FAIXA_ETARIA_4_2021, TP_FAIXA_ETARIA_5_2021, TP_FAIXA_ETARIA_6_2021, TP_FAIXA_ETARIA_7_2021, TP_FAIXA_ETARIA_8_2021, TP_FAIXA_ETARIA_9_2021, TP_FAIXA_ETARIA_10_2021, TP_FAIXA_ETARIA_11_2021, TP_FAIXA_ETARIA_12_2021, TP_FAIXA_ETARIA_13_2021, TP_FAIXA_ETARIA_14_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_Faixa_Etaria_2021, align='center', color=['red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por faixa etaria")
plt.ylabel("Faixa etaria por ano")
# Out:
# Numero total de participantes com faixa etária 1 (menor de 17 anos) na planilha Microdados Enem 2021: 4200
# Numero total de participantes com faixa etária 2 (17 anos) na planilha Microdados Enem 2021: 11126
# Numero total de participantes com faixa etária 3 (18 anos) na planilha Microdados Enem 2021: 14066
# Numero total de participantes com faixa etária 4 (19 anos) na planilha Microdados Enem 2021: 8034
# Numero total de participantes com faixa etária 5 (20 anos) na planilha Microdados Enem 2021: 4890
# Numero total de participantes com faixa etária 6 (21 anos) na planilha Microdados Enem 2021: 3509
# Numero total de participantes com faixa etária 7 (22 anos) na planilha Microdados Enem 2021: 2674
# Numero total de participantes com faixa etária 8 (23 anos) na planilha Microdados Enem 2021: 2164
# Numero total de participantes com faixa etária 9 (24 anos) na planilha Microdados Enem 2021: 1822
# ...

# %%
#---------------------------------- Grafico 5 - Faixa etaria por ano 2020 ----------------------------------

#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==1)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==2)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==3)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==4)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==5)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==6)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==7)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==8)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==9)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==10)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==11)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==12)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==13)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==14)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==15)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==16)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==17)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==18)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==19)])
#display(planilha2020.loc[(planilha2020['TP_FAIXA_ETARIA']==20)])

TP_FAIXA_ETARIA_1_2020 = 4741
TP_FAIXA_ETARIA_2_2020 = 13776
TP_FAIXA_ETARIA_3_2020 = 16973
TP_FAIXA_ETARIA_4_2020 = 11954
TP_FAIXA_ETARIA_5_2020 = 9199
TP_FAIXA_ETARIA_6_2020 = 7293
TP_FAIXA_ETARIA_7_2020 = 6086
TP_FAIXA_ETARIA_8_2020 = 4999
TP_FAIXA_ETARIA_9_2020 = 4430
TP_FAIXA_ETARIA_10_2020 = 3904
TP_FAIXA_ETARIA_11_2020 = 12602
TP_FAIXA_ETARIA_12_2020 = 7336
TP_FAIXA_ETARIA_13_2020 = 5391
TP_FAIXA_ETARIA_14_2020 = 8248

# Printar total de participantes por sexo
print('Numero total de participantes com faixa etária 1 (menor de 17 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_1_2020)
print('Numero total de participantes com faixa etária 2 (17 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_2_2020)
print('Numero total de participantes com faixa etária 3 (18 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_3_2020)
print('Numero total de participantes com faixa etária 4 (19 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_4_2020)
print('Numero total de participantes com faixa etária 5 (20 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_5_2020)
print('Numero total de participantes com faixa etária 6 (21 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_6_2020)
print('Numero total de participantes com faixa etária 7 (22 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_7_2020)
print('Numero total de participantes com faixa etária 8 (23 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_8_2020)
print('Numero total de participantes com faixa etária 9 (24 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_9_2020)
print('Numero total de participantes com faixa etária 10 (25 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_10_2020)
print('Numero total de participantes com faixa etária 11 (entre 26 e 30 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_11_2020)
print('Numero total de participantes com faixa etária 12 (entre 31 e 35 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_12_2020)
print('Numero total de participantes com faixa etária 13 (entre 36 e 40 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_13_2020)
print('Numero total de participantes com faixa etária 20 (maiores de 41 anos) na planilha Microdados Enem 2020:', TP_FAIXA_ETARIA_14_2020,'\n')

# Printando grafico de barras horizontal
x = ['Menor de 17 anos 2020', '17 anos 2020', '18 anos 2020', '19 anos 2020', '20 anos 2020', '21 anos 2020', '22 anos 2020', '23 anos 2020', '24 anos 2020', '25 anos 2020', 'Entre 26 e 30 anos 2020', 'Entre 31 e 35 anos 2020', 'Entre 36 e 40 anos 2020', 'Maiores de 41 anos 2020']
y = [TP_FAIXA_ETARIA_1_2020, TP_FAIXA_ETARIA_2_2020, TP_FAIXA_ETARIA_3_2020, TP_FAIXA_ETARIA_4_2020, TP_FAIXA_ETARIA_5_2020, TP_FAIXA_ETARIA_6_2020, TP_FAIXA_ETARIA_7_2020, TP_FAIXA_ETARIA_8_2020, TP_FAIXA_ETARIA_9_2020, TP_FAIXA_ETARIA_10_2020, TP_FAIXA_ETARIA_11_2020, TP_FAIXA_ETARIA_12_2020, TP_FAIXA_ETARIA_13_2020, TP_FAIXA_ETARIA_14_2020] 
total_Faixa_Etaria_2020 = TP_FAIXA_ETARIA_1_2020, TP_FAIXA_ETARIA_2_2020, TP_FAIXA_ETARIA_3_2020, TP_FAIXA_ETARIA_4_2020, TP_FAIXA_ETARIA_5_2020, TP_FAIXA_ETARIA_6_2020, TP_FAIXA_ETARIA_7_2020, TP_FAIXA_ETARIA_8_2020, TP_FAIXA_ETARIA_9_2020, TP_FAIXA_ETARIA_10_2020, TP_FAIXA_ETARIA_11_2020, TP_FAIXA_ETARIA_12_2020, TP_FAIXA_ETARIA_13_2020, TP_FAIXA_ETARIA_14_2020

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_Faixa_Etaria_2020, align='center', color=['blue'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por faixa etaria")
plt.ylabel("Faixa etaria por ano")
# Out:
# Numero total de participantes com faixa etária 1 (menor de 17 anos) na planilha Microdados Enem 2020: 4741
# Numero total de participantes com faixa etária 2 (17 anos) na planilha Microdados Enem 2020: 13776
# Numero total de participantes com faixa etária 3 (18 anos) na planilha Microdados Enem 2020: 16973
# Numero total de participantes com faixa etária 4 (19 anos) na planilha Microdados Enem 2020: 11954
# Numero total de participantes com faixa etária 5 (20 anos) na planilha Microdados Enem 2020: 9199
# Numero total de participantes com faixa etária 6 (21 anos) na planilha Microdados Enem 2020: 7293
# Numero total de participantes com faixa etária 7 (22 anos) na planilha Microdados Enem 2020: 6086
# Numero total de participantes com faixa etária 8 (23 anos) na planilha Microdados Enem 2020: 4999
# Numero total de participantes com faixa etária 9 (24 anos) na planilha Microdados Enem 2020: 4430
# ...

# %%
# Histograma projetando a quatidade de participantes por idade nos dos dois anos
print(planilha2020.TP_FAIXA_ETARIA.hist())
print(planilha2021.TP_FAIXA_ETARIA.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 6 - Cor/raca por ano 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['TP_COR_RACA']==0)])
#display(planilha2021.loc[(planilha2021['TP_COR_RACA']==1)])
#display(planilha2021.loc[(planilha2021['TP_COR_RACA']==2)])
#display(planilha2021.loc[(planilha2021['TP_COR_RACA']==3)])
#display(planilha2021.loc[(planilha2021['TP_COR_RACA']==4)])
#display(planilha2021.loc[(planilha2021['TP_COR_RACA']==5)])

TP_COR_RACA_0_2021 = 1718
TP_COR_RACA_1_2021 = 26097
TP_COR_RACA_2_2021 = 9126
TP_COR_RACA_3_2021 = 28812
TP_COR_RACA_4_2021 = 1539
TP_COR_RACA_5_2021 = 209

print('Numero total de participantes com cor/raca 0 (não informado) na planilha Microdados Enem 2021:', TP_COR_RACA_0_2021)
print('Numero total de participantes com cor/raca 1 (branca) na planilha Microdados Enem 2021:', TP_COR_RACA_1_2021)
print('Numero total de participantes com cor/raca 2 (preta) na planilha Microdados Enem 2021:', TP_COR_RACA_2_2021)
print('Numero total de participantes com cor/raca 3 (parda) na planilha Microdados Enem 2021:', TP_COR_RACA_3_2021)
print('Numero total de participantes com cor/raca 4 (amarela) na planilha Microdados Enem 2021:', TP_COR_RACA_4_2021)
print('Numero total de participantes com cor/raca 5 (indigena) na planilha Microdados Enem 2021:', TP_COR_RACA_5_2021, '\n')

# Printando grafico de barras horizontal
x = ['Cor/raca 0 (não informado) 2021', 'Cor/raca 1 (branca) 2021', 'Cor/raca 2 (preta) 2021', 'Cor/raca 3 (parda) 2021', 'Cor/raca 4 (amarela) 2021', 'Cor/raca 5 (indigena) 2021']
y = [TP_COR_RACA_0_2021, TP_COR_RACA_1_2021, TP_COR_RACA_2_2021, TP_COR_RACA_3_2021, TP_COR_RACA_4_2021, TP_COR_RACA_5_2021]
total_TP_COR_RACA_2021 = TP_COR_RACA_0_2021, TP_COR_RACA_1_2021, TP_COR_RACA_2_2021, TP_COR_RACA_3_2021, TP_COR_RACA_4_2021, TP_COR_RACA_5_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_TP_COR_RACA_2021, align='center', color=['red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por cor/raca")
plt.ylabel("Cor/raça por ano")
# Out:
# Numero total de participantes com cor/raca 0 (não informado) na planilha Microdados Enem 2021: 1718
# Numero total de participantes com cor/raca 1 (branca) na planilha Microdados Enem 2021: 26097
# Numero total de participantes com cor/raca 2 (preta) na planilha Microdados Enem 2021: 9126
# Numero total de participantes com cor/raca 3 (parda) na planilha Microdados Enem 2021: 28812
# Numero total de participantes com cor/raca 4 (amarela) na planilha Microdados Enem 2021: 1539
# Numero total de participantes com cor/raca 5 (indigena) na planilha Microdados Enem 2021: 209
# Text(0, 0.5, 'Cor/raça por ano')

# %%
#---------------------------------- Grafico 7 - Cor/raca por ano 2020 ----------------------------------

#display(planilha2020.loc[(planilha2020['TP_COR_RACA']==0)])
#display(planilha2020.loc[(planilha2020['TP_COR_RACA']==1)])
#display(planilha2020.loc[(planilha2020['TP_COR_RACA']==2)])
#display(planilha2020.loc[(planilha2020['TP_COR_RACA']==3)])
#display(planilha2020.loc[(planilha2020['TP_COR_RACA']==4)])
#display(planilha2020.loc[(planilha2020['TP_COR_RACA']==5)])

TP_COR_RACA_0_2020 = 2828
TP_COR_RACA_1_2020 = 36205
TP_COR_RACA_2_2020 = 17853
TP_COR_RACA_3_2020 = 56256
TP_COR_RACA_4_2020 = 3274
TP_COR_RACA_5_2020 = 516

print('Numero total de participantes com cor/raca 0 (não informado) na planilha Microdados Enem 2020:', TP_COR_RACA_0_2020)
print('Numero total de participantes com cor/raca 1 (branca) na planilha Microdados Enem 2020:', TP_COR_RACA_1_2020)
print('Numero total de participantes com cor/raca 2 (preta) na planilha Microdados Enem 2020:', TP_COR_RACA_2_2020)
print('Numero total de participantes com cor/raca 3 (parda) na planilha Microdados Enem 2020:', TP_COR_RACA_3_2020)
print('Numero total de participantes com cor/raca 4 (amarela) na planilha Microdados Enem 2020:', TP_COR_RACA_4_2020)
print('Numero total de participantes com cor/raca 5 (indigena) na planilha Microdados Enem 2020:', TP_COR_RACA_5_2020, '\n')

# Printando grafico de barras horizontal
x = ['Cor/raca 0 (não informado) 2020', 'Cor/raca 1 (branca) 2020', 'Cor/raca 2 (preta) 2020', 'Cor/raca 3 (parda) 2020', 'Cor/raca 4 (amarela) 2020', 'Cor/raca 5 (indigena) 2020']
y = [TP_COR_RACA_0_2020, TP_COR_RACA_1_2020, TP_COR_RACA_2_2020, TP_COR_RACA_3_2020, TP_COR_RACA_4_2020, TP_COR_RACA_5_2020]
total_TP_COR_RACA_2020 = TP_COR_RACA_0_2020, TP_COR_RACA_1_2020, TP_COR_RACA_2_2020, TP_COR_RACA_3_2020, TP_COR_RACA_4_2020, TP_COR_RACA_5_2020

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_TP_COR_RACA_2020, align='center', color=['blue'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por cor/raca")
plt.ylabel("Cor/raca por ano")
# Out:
# Numero total de participantes com cor/raca 0 (não informado) na planilha Microdados Enem 2020: 2828
# Numero total de participantes com cor/raca 1 (branca) na planilha Microdados Enem 2020: 36205
# Numero total de participantes com cor/raca 2 (preta) na planilha Microdados Enem 2020: 17853
# Numero total de participantes com cor/raca 3 (parda) na planilha Microdados Enem 2020: 56256
# Numero total de participantes com cor/raca 4 (amarela) na planilha Microdados Enem 2020: 3274
# Numero total de participantes com cor/raca 5 (indigena) na planilha Microdados Enem 2020: 516
# Text(0, 0.5, 'Cor/raca por ano')

# %%
# Histograma projetando a quatidade de participantes por raça nos dos dois anos
print(planilha2020.TP_COR_RACA.hist())
print(planilha2021.TP_COR_RACA.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 8 - Tipo de escola do ensino medio por ano 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['TP_ESCOLA']==1)])
#display(planilha2021.loc[(planilha2021['TP_ESCOLA']==2)])
#display(planilha2021.loc[(planilha2021['TP_ESCOLA']==3)])
#display(planilha2021.loc[(planilha2021['TP_ESCOLA']==4)])

TP_ESCOLA_1_2021 = 45912 
TP_ESCOLA_2_2021 = 15949
TP_ESCOLA_3_2021 = 5640
TP_ESCOLA_4_2021 = 0

print('Numero total de participantes com tipo de escola 1 (não respondeu) na planilha Microdados Enem 2021:', TP_ESCOLA_1_2021)
print('Numero total de participantes com tipo de escola 2 (publica) na planilha Microdados Enem 2021:', TP_ESCOLA_2_2021)
print('Numero total de participantes com tipo de escola 3 (privada) na planilha Microdados Enem 2021:', TP_ESCOLA_3_2021)
print('Numero total de participantes com tipo de escola 4 (exterior) na planilha Microdados Enem 2021:', TP_ESCOLA_4_2021, '\n')

# Printando grafico de barras horizontal
x = ['Tipo de escola 1 (não respondeu) 2021', 'Tipo de escola 2 (publica) 2021', 'Tipo de escola 3 (privada) 2021', 'Tipo de escola 4 (exterior) 2021']
y = [TP_ESCOLA_1_2021, TP_ESCOLA_2_2021, TP_ESCOLA_3_2021, TP_ESCOLA_4_2021]

total_TP_ESCOLA_2021 = TP_ESCOLA_1_2021, TP_ESCOLA_2_2021, TP_ESCOLA_3_2021, TP_ESCOLA_4_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_TP_ESCOLA_2021, align='center', color=['red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes tipo de escola do ensino medio")
plt.ylabel("Tipo de escola do ensino medio por ano")
# Out:
# Numero total de participantes com tipo de escola 1 (não respondeu) na planilha Microdados Enem 2021: 45912
# Numero total de participantes com tipo de escola 2 (publica) na planilha Microdados Enem 2021: 15949
# Numero total de participantes com tipo de escola 3 (privada) na planilha Microdados Enem 2021: 5640
# Numero total de participantes com tipo de escola 4 (exterior) na planilha Microdados Enem 2021: 0
# Text(0, 0.5, 'Tipo de escola do ensino medio por ano')

# %%
#---------------------------------- Grafico 9 - Tipo de escola do ensino medio por ano 2020 ----------------------------------

#display(planilha2020.loc[(planilha2020['TP_ESCOLA']==1)])
#display(planilha2020.loc[(planilha2020['TP_ESCOLA']==2)])
#display(planilha2020.loc[(planilha2020['TP_ESCOLA']==3)])
#display(planilha2020.loc[(planilha2020['TP_ESCOLA']==4)])

TP_ESCOLA_1_2020 = 89555 
TP_ESCOLA_2_2020 = 21191
TP_ESCOLA_3_2020 = 6186
TP_ESCOLA_4_2020 = 0

print('Numero total de participantes com tipo de escola 1 (não respondeu) na planilha Microdados Enem 2020:', TP_ESCOLA_1_2020)
print('Numero total de participantes com tipo de escola 2 (publica) na planilha Microdados Enem 2020:', TP_ESCOLA_2_2020)
print('Numero total de participantes com tipo de escola 3 (privada) na planilha Microdados Enem 2020:', TP_ESCOLA_3_2020)
print('Numero total de participantes com tipo de escola 4 (exterior) na planilha Microdados Enem 2020:', TP_ESCOLA_4_2020, '\n')

# Printando grafico de barras horizontal
x = ['Tipo de escola 1 (não respondeu) 2020', 'Tipo de escola 2 (publica) 2020', 'Tipo de escola 3 (privada) 2020', 'Tipo de escola 4 (exterior) 2020']
y = [TP_ESCOLA_1_2020, TP_ESCOLA_2_2020, TP_ESCOLA_3_2020, TP_ESCOLA_4_2020]

total_TP_ESCOLA_2020 = TP_ESCOLA_1_2020, TP_ESCOLA_2_2020, TP_ESCOLA_3_2020, TP_ESCOLA_4_2020

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_TP_ESCOLA_2020, align='center', color=['blue'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes tipo de escola do ensino medio")
plt.ylabel("Tipo de escola do ensino medio por ano")
# Out:
# Numero total de participantes com tipo de escola 1 (não respondeu) na planilha Microdados Enem 2020: 89555
# Numero total de participantes com tipo de escola 2 (publica) na planilha Microdados Enem 2020: 21191
# Numero total de participantes com tipo de escola 3 (privada) na planilha Microdados Enem 2020: 6186
# Numero total de participantes com tipo de escola 4 (exterior) na planilha Microdados Enem 2020: 0
# Text(0, 0.5, 'Tipo de escola do ensino medio por ano')

# %%
# Histograma projetando a quatidade de participantes por tipo de escola do ensino medio
print(planilha2020.TP_ESCOLA.hist())
print(planilha2021.TP_ESCOLA.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 10 - tipo de renda mensal familiar 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['Q006']=='A')])
#display(planilha2021.loc[(planilha2021['Q006']=='B')])
#display(planilha2021.loc[(planilha2021['Q006']=='C')])
#display(planilha2021.loc[(planilha2021['Q006']=='D')])
#display(planilha2021.loc[(planilha2021['Q006']=='E')])
#display(planilha2021.loc[(planilha2021['Q006']=='F')])
#display(planilha2021.loc[(planilha2021['Q006']=='G')])
#display(planilha2021.loc[(planilha2021['Q006']=='H')])
#display(planilha2021.loc[(planilha2021['Q006']=='I')])
#display(planilha2021.loc[(planilha2021['Q006']=='J')])
#display(planilha2021.loc[(planilha2021['Q006']=='K')])
#display(planilha2021.loc[(planilha2021['Q006']=='L')])
#display(planilha2021.loc[(planilha2021['Q006']=='M')])
#display(planilha2021.loc[(planilha2021['Q006']=='N')])
#display(planilha2021.loc[(planilha2021['Q006']=='O')])
#display(planilha2021.loc[(planilha2021['Q006']=='P')])
#display(planilha2021.loc[(planilha2021['Q006']=='Q')])

Q006_A_2021 = 2327 
Q006_B_2021 = 12968 
Q006_C_2021 = 19175
Q006_D_2021 = 7829
Q006_E_2021 = 6717
Q006_F_2021 = 4151
Q006_G_2021 = 7029
Q006_H_2021 = 7305

print('Numero total de participantes que responderam A (nenhuma renda) para renda familiar na planilha Microdados Enem 2021:', Q006_A_2021)
print('Numero total de participantes que responderam B (ate R$1.045,00) para renda familiar na planilha Microdados Enem 2021:', Q006_B_2021)
print('Numero total de participantes que responderam C (de R$1.045,00 ate R$2.090,00) para renda familiar na planilha Microdados Enem 2021:', Q006_C_2021)
print('Numero total de participantes que responderam D (de R$2.090,00 ate R$3.135,00) para renda familiar na planilha Microdados Enem 2021:', Q006_D_2021)
print('Numero total de participantes que responderam E (de R$3.135,00 ate R$5.225,00) para renda familiar na planilha Microdados Enem 2021:', Q006_E_2021)
print('Numero total de participantes que responderam F (de R$5.225,00 ate R$7.315,00) para renda familiar na planilha Microdados Enem 2021:', Q006_F_2021)
print('Numero total de participantes que responderam G (de R$7.315,00 ate R$ 12.540,01) para renda familiar na planilha Microdados Enem 2021:', Q006_G_2021)
print('Numero total de participantes que responderam H (acima de R$ 12.540,01) para renda familiar na planilha Microdados Enem 2021:', Q006_H_2021, '\n')


# Printando grafico de barras horizontal
x = ['A (nenhuma renda) 2021', 'B (ate R$1.045,00) 2021', 'C (de R$1.045,00 ate R$2.090,00) 2021', 'D (de R$2.090,00 ate R$3.135,00) 2021', 'E (de R$3.135,00 ate R$5.225,00) 2021', 'F (de R$5.225,00 ate R$7.315,00) 2021', 'G (de R$7.315,00 ate R$12.540,01) 2021', 'H (acima de R$12.540,01) 2021']
y = [Q006_A_2021, Q006_B_2021, Q006_C_2021, Q006_D_2021, Q006_E_2021, Q006_F_2021, Q006_G_2021, Q006_H_2021]
total_Q006_2021 = Q006_A_2021, Q006_B_2021, Q006_C_2021, Q006_D_2021, Q006_E_2021, Q006_F_2021, Q006_G_2021, Q006_H_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_Q006_2021, align='center', color=['red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por tipo de renda")
plt.ylabel("Resposta participante para tipo de renda")
# Out:
# Numero total de participantes que responderam A (nenhuma renda) para renda familiar na planilha Microdados Enem 2021: 2327
# Numero total de participantes que responderam B (ate R$1.045,00) para renda familiar na planilha Microdados Enem 2021: 12968
# Numero total de participantes que responderam C (de R$1.045,00 ate R$2.090,00) para renda familiar na planilha Microdados Enem 2021: 19175
# Numero total de participantes que responderam D (de R$2.090,00 ate R$3.135,00) para renda familiar na planilha Microdados Enem 2021: 7829
# Numero total de participantes que responderam E (de R$3.135,00 ate R$5.225,00) para renda familiar na planilha Microdados Enem 2021: 6717
# Numero total de participantes que responderam F (de R$5.225,00 ate R$7.315,00) para renda familiar na planilha Microdados Enem 2021: 4151
# Numero total de participantes que responderam G (de R$7.315,00 ate R$ 12.540,01) para renda familiar na planilha Microdados Enem 2021: 7029
# ...

# %%
#---------------------------------- Grafico 11 - tipo de renda mensal familiar 2020 ----------------------------------

#display(planilha2020.loc[(planilha2020['Q006']=='A')])
#display(planilha2020.loc[(planilha2020['Q006']=='B')])
#display(planilha2020.loc[(planilha2020['Q006']=='C')])
#display(planilha2020.loc[(planilha2020['Q006']=='D')])
#display(planilha2020.loc[(planilha2020['Q006']=='E')])
#display(planilha2020.loc[(planilha2020['Q006']=='F')])
#display(planilha2020.loc[(planilha2020['Q006']=='G')])
#display(planilha2020.loc[(planilha2020['Q006']=='H')])
#display(planilha2020.loc[(planilha2020['Q006']=='I')])
#display(planilha2020.loc[(planilha2020['Q006']=='J')])
#display(planilha2020.loc[(planilha2020['Q006']=='K')])
#display(planilha2020.loc[(planilha2020['Q006']=='L')])
#display(planilha2020.loc[(planilha2020['Q006']=='M')])
#display(planilha2020.loc[(planilha2020['Q006']=='N')])
#display(planilha2020.loc[(planilha2020['Q006']=='O')])
#display(planilha2020.loc[(planilha2020['Q006']=='P')])
#display(planilha2020.loc[(planilha2020['Q006']=='Q')])

Q006_A_2020 = 5952
Q006_B_2020 = 29670
Q006_C_2020 = 35718
Q006_D_2020 = 12974
Q006_E_2020 = 8786
Q006_F_2020 = 4718
Q006_G_2020 = 7333
Q006_H_2020 = 8019

print('Numero total de participantes que responderam A (nenhuma renda) para renda familiar na planilha Microdados Enem 2020:', Q006_A_2020)
print('Numero total de participantes que responderam B (ate R$1.045,00) para renda familiar na planilha Microdados Enem 2020:', Q006_B_2020)
print('Numero total de participantes que responderam C (de R$1.045,00 ate R$2.090,00) para renda familiar na planilha Microdados Enem 2020:', Q006_C_2020)
print('Numero total de participantes que responderam D (de R$2.090,00 ate R$3.135,00) para renda familiar na planilha Microdados Enem 2020:', Q006_D_2020)
print('Numero total de participantes que responderam E (de R$3.135,00 ate R$5.225,00) para renda familiar na planilha Microdados Enem 2020:', Q006_E_2020)
print('Numero total de participantes que responderam F (de R$5.225,00 ate R$7.315,00) para renda familiar na planilha Microdados Enem 2020:', Q006_F_2020)
print('Numero total de participantes que responderam G (de R$7.315,00 ate R$ 12.540,01) para renda familiar na planilha Microdados Enem 2020:', Q006_G_2020)
print('Numero total de participantes que responderam H (acima de R$ 12.540,01) para renda familiar na planilha Microdados Enem 2020:', Q006_H_2020, '\n')


# Printando grafico de barras horizontal
x = ['A (nenhuma renda) 2020', 'B (ate R$1.045,00) 2020', 'C (de R$1.045,00 ate R$2.090,00) 2020', 'D (de R$2.090,00 ate R$3.135,00) 2020', 'E (de R$3.135,00 ate R$5.225,00) 2020', 'F (de R$5.225,00 ate R$7.315,00) 2020', 'G (de R$7.315,00 ate R$12.540,01) 2020', 'H (acima de R$12.540,01) 2020']
y = [Q006_A_2020, Q006_B_2020, Q006_C_2020, Q006_D_2020, Q006_E_2020, Q006_F_2020, Q006_G_2020, Q006_H_2020]
total_Q006_2020 = Q006_A_2020, Q006_B_2020, Q006_C_2020, Q006_D_2020, Q006_E_2020, Q006_F_2020, Q006_G_2020, Q006_H_2020

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_Q006_2020, align='center', color=['blue'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por tipo de renda")
plt.ylabel("Resposta participante para tipo de renda")
# Out:
# Numero total de participantes que responderam A (nenhuma renda) para renda familiar na planilha Microdados Enem 2020: 5952
# Numero total de participantes que responderam B (ate R$1.045,00) para renda familiar na planilha Microdados Enem 2020: 29670
# Numero total de participantes que responderam C (de R$1.045,00 ate R$2.090,00) para renda familiar na planilha Microdados Enem 2020: 35718
# Numero total de participantes que responderam D (de R$2.090,00 ate R$3.135,00) para renda familiar na planilha Microdados Enem 2020: 12974
# Numero total de participantes que responderam E (de R$3.135,00 ate R$5.225,00) para renda familiar na planilha Microdados Enem 2020: 8786
# Numero total de participantes que responderam F (de R$5.225,00 ate R$7.315,00) para renda familiar na planilha Microdados Enem 2020: 4718
# Numero total de participantes que responderam G (de R$7.315,00 ate R$ 12.540,01) para renda familiar na planilha Microdados Enem 2020: 7333
# ...

# %%
# Histograma projetando a quatidade de participantes por tipo de renda mensal familiar 
print(planilha2020.Q006.hist())
print(planilha2021.Q006.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 12 - Acesso a telefone celular 2020 e 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['Q022'] == 'A')])
#display(planilha2021.loc[(planilha2021['Q022'] == 'B')])
#display(planilha2021.loc[(planilha2021['Q022'] == 'C')])
#display(planilha2021.loc[(planilha2021['Q022'] == 'D')])
#display(planilha2021.loc[(planilha2021['Q022'] == 'E')])

#display(planilha2020.loc[(planilha2020['Q022'] == 'A')])
#display(planilha2020.loc[(planilha2020['Q022'] == 'B')])
#display(planilha2020.loc[(planilha2020['Q022'] == 'C')])
#display(planilha2020.loc[(planilha2020['Q022'] == 'D')])
#display(planilha2020.loc[(planilha2020['Q022'] == 'E')])

Q022_A_2020 = 1158 
Q022_B_2020 = 9402 
Q022_C_2020 = 16060 
Q022_D_2020 = 19574
Q022_E_2020 = 21307 

Q022_A_2021 = 2109 
Q022_B_2021 = 22584 
Q022_C_2021 = 31906 
Q022_D_2021 = 30029 
Q022_E_2021 = 26542 

print('Numero total de participantes que responderam A (não) para acesso a internet na planilha Microdados Enem 2021:', Q022_A_2021)
print('Numero total de participantes que responderam B (sim, um) para acesso a internet na planilha Microdados Enem 2021:', Q022_B_2021)
print('Numero total de participantes que responderam C (sim, dois) para acesso a internet na planilha Microdados Enem 2021:', Q022_C_2021)
print('Numero total de participantes que responderam D (sim, três) para acesso a internet na planilha Microdados Enem 2021:', Q022_D_2021)
print('Numero total de participantes que responderam E (sim, quatro ou mais) para acesso a internet na planilha Microdados Enem 2021:', Q022_E_2021, '\n')

print('Numero total de participantes que responderam A (não) para acesso a internet na planilha Microdados Enem 2020:', Q022_A_2020)
print('Numero total de participantes que responderam B (sim, um) para acesso a internet na planilha Microdados Enem 2020:', Q022_B_2020)
print('Numero total de participantes que responderam C (sim, dois) para acesso a internet na planilha Microdados Enem 2020:', Q022_C_2020)
print('Numero total de participantes que responderam D (sim, três) para acesso a internet na planilha Microdados Enem 2020:', Q022_D_2020)
print('Numero total de participantes que responderam E (sim, quatro ou mais) para acesso a internet na planilha Microdados Enem 2020:', Q022_E_2020, '\n')

# Printando grafico de barras horizontal
x = ['A (não) 2021', 'B (sim, um) 2021', 'C (sim, dois) 2021', 'D (sim, três) 2021', 'E (sim, quatro ou mais) 2021', 'A (não) 2020', 'B (sim, um) 2020', 'C (sim, dois) 2020', 'D (sim, três) 2020', 'E (sim, quatro ou mais) 2020']
y = [Q022_A_2020, Q022_B_2020, Q022_C_2020, Q022_D_2020, Q022_E_2020, Q022_A_2021, Q022_B_2021, Q022_C_2021, Q022_D_2021, Q022_E_2021]

total_Q022_A_B = Q022_A_2020, Q022_B_2020, Q022_C_2020, Q022_D_2020, Q022_E_2020, Q022_A_2021, Q022_B_2021, Q022_C_2021, Q022_D_2021, Q022_E_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_Q022_A_B, align='center', color=['blue', 'blue', 'blue', 'blue', 'blue', 'red', 'red', 'red', 'red', 'red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por tipo de acesso a telefone celular")
plt.ylabel("Resposta participante para acesso a telefone celular")
# Out:
# Numero total de participantes que responderam A (não) para acesso a internet na planilha Microdados Enem 2021: 2109
# Numero total de participantes que responderam B (sim, um) para acesso a internet na planilha Microdados Enem 2021: 22584
# Numero total de participantes que responderam C (sim, dois) para acesso a internet na planilha Microdados Enem 2021: 31906
# Numero total de participantes que responderam D (sim, três) para acesso a internet na planilha Microdados Enem 2021: 30029
# Numero total de participantes que responderam E (sim, quatro ou mais) para acesso a internet na planilha Microdados Enem 2021: 26542
#
# Numero total de participantes que responderam A (não) para acesso a internet na planilha Microdados Enem 2020: 1158
# Numero total de participantes que responderam B (sim, um) para acesso a internet na planilha Microdados Enem 2020: 9402
# Numero total de participantes que responderam C (sim, dois) para acesso a internet na planilha Microdados Enem 2020: 16060
# ...

# %%
# Histograma projetando a quatidade de participantes por acesso a celular
print(planilha2020.Q022.hist())
print(planilha2021.Q022.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 13 - Acesso a internet 2020 e 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['Q025'] == 'B')])
#display(planilha2021.loc[(planilha2021['Q025'] == 'A')])
#display(planilha2020.loc[(planilha2020['Q025'] == 'B')])
#display(planilha2020.loc[(planilha2020['Q025'] == 'A')])

Q025_B_2021 = 63770
Q025_A_2021 = 3731

Q025_B_2020 = 98667
Q025_A_2020 = 14503

print('Numero total de participantes que responderam B (sim) para acesso a internet na planilha Microdados Enem 2021:', Q025_B_2021)
print('Numero total de participantes que responderam A (não) para acesso a internet na planilha Microdados Enem 2021:', Q025_A_2021, '\n')

print('Numero total de participantes que responderam B (sim) para acesso a internet na planilha Microdados Enem 2020:', Q025_B_2020)
print('Numero total de participantes que responderam A (não) para acesso a internet na planilha Microdados Enem 2020:', Q025_A_2020, '\n')

# Printando grafico de barras horizontal
x = ['B (sim) 2020', 'A (não) 2020', 'B (sim) 2021', 'A (não) 2021']
y = [Q025_B_2020, Q025_A_2020, Q025_B_2021, Q025_A_2021]

total_Q025_A_B = Q025_B_2020, Q025_A_2020, Q025_B_2021, Q025_A_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_Q025_A_B, align='center', color=['blue', 'blue', 'red', 'red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por acesso a internet")
plt.ylabel("Resposta participante para acesso a internet")
# Out:
# Numero total de participantes que responderam B (sim) para acesso a internet na planilha Microdados Enem 2021: 63770
# Numero total de participantes que responderam A (não) para acesso a internet na planilha Microdados Enem 2021: 3731
#
# Numero total de participantes que responderam B (sim) para acesso a internet na planilha Microdados Enem 2020: 98667
# Numero total de participantes que responderam A (não) para acesso a internet na planilha Microdados Enem 2020: 14503
# Text(0, 0.5, 'Resposta participante para acesso a internet')

# %%
# Histograma projetando a quatidade de participantes por acessi a internet
print(planilha2020.Q025.hist())
print(planilha2021.Q025.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 14 - Presença na prova ciencias da natureza 2020 e 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['TP_PRESENCA_CN'] == 0)])
#display(planilha2021.loc[(planilha2021['TP_PRESENCA_CN'] == 1)])
#display(planilha2021.loc[(planilha2021['TP_PRESENCA_CN'] == 2)])

#display(planilha2020.loc[(planilha2020['TP_PRESENCA_CN'] == 0)])
#display(planilha2020.loc[(planilha2020['TP_PRESENCA_CN'] == 1)])
#display(planilha2020.loc[(planilha2020['TP_PRESENCA_CN'] == 2)])

TP_PRESENCA_CN_0_2021 = 22319
TP_PRESENCA_CN_1_2021 = 45160
TP_PRESENCA_CN_2_2021 = 22

TP_PRESENCA_CN_0_2020 = 63922
TP_PRESENCA_CN_1_2020 = 52987
TP_PRESENCA_CN_2_2020 = 23

print('Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2021:', TP_PRESENCA_CN_0_2021)
print('Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2021:', TP_PRESENCA_CN_1_2021)
print('Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2021:', TP_PRESENCA_CN_2_2021, '\n')

print('Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2020:', TP_PRESENCA_CN_0_2020)
print('Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2020:', TP_PRESENCA_CN_1_2020)
print('Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2020:', TP_PRESENCA_CN_2_2020, '\n')

# Printando grafico de barras horizontal
x = ['0 (faltou à prova) 2020', '1 (presente na prova) 2020', '2 (eliminado na prova) 2020', '0 (faltou à prova) 2021', '1 (presente na prova) 2021', '2 (eliminado na prova) 2021']
y = [TP_PRESENCA_CN_0_2020, TP_PRESENCA_CN_1_2020, TP_PRESENCA_CN_2_2020, TP_PRESENCA_CN_0_2021, TP_PRESENCA_CN_1_2021, TP_PRESENCA_CN_2_2021]

total_TP_PRESENCA_CN = TP_PRESENCA_CN_0_2020, TP_PRESENCA_CN_1_2020, TP_PRESENCA_CN_2_2020, TP_PRESENCA_CN_0_2021, TP_PRESENCA_CN_1_2021, TP_PRESENCA_CN_2_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_TP_PRESENCA_CN, align='center', color=['blue', 'blue', 'blue', 'red', 'red', 'red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes tipo de presença na prova de ciências da natureza")
plt.ylabel("Tipo de presença na prova")
# Out:
# Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2021: 22319
# Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2021: 45160
# Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2021: 22
#
# Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2020: 63922
# Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2020: 52987
# Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2020: 23
# Text(0, 0.5, 'Tipo de presença na prova')

# %%
# Histograma projetando a presença de participantes na prova de ciencias da natureza
print(planilha2020.TP_PRESENCA_CN.hist())
print(planilha2021.TP_PRESENCA_CN.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 15 - Presença na prova ciencias da humanas 2020 e 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['TP_PRESENCA_CH'] == 0)])
#display(planilha2021.loc[(planilha2021['TP_PRESENCA_CH'] == 1)])
#display(planilha2021.loc[(planilha2021['TP_PRESENCA_CH'] == 2)])

#display(planilha2020.loc[(planilha2020['TP_PRESENCA_CH'] == 0)])
#display(planilha2020.loc[(planilha2020['TP_PRESENCA_CH'] == 1)])
#display(planilha2020.loc[(planilha2020['TP_PRESENCA_CH'] == 2)])

TP_PRESENCA_CH_0_2021 = 19615
TP_PRESENCA_CH_1_2021 = 47817
TP_PRESENCA_CH_2_2021 = 69

TP_PRESENCA_CH_0_2020 = 60673
TP_PRESENCA_CH_1_2020 = 56152
TP_PRESENCA_CH_2_2020 = 107

print('Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2021:', TP_PRESENCA_CH_0_2021)
print('Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2021:', TP_PRESENCA_CH_1_2021 )
print('Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2021:', TP_PRESENCA_CH_2_2021, '\n')

print('Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2020:', TP_PRESENCA_CH_0_2020)
print('Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2020:', TP_PRESENCA_CH_1_2020 )
print('Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2020:', TP_PRESENCA_CH_2_2020, '\n')

# Printando grafico de barras horizontal
x = ['0 (faltou à prova) 2020', '1 (presente na prova) 2020', '2 (eliminado na prova) 2020', '0 (faltou à prova) 2021', '1 (presente na prova) 2021', '2 (eliminado na prova) 2021']
y = [TP_PRESENCA_CH_0_2020, TP_PRESENCA_CH_1_2020, TP_PRESENCA_CH_2_2020, TP_PRESENCA_CH_0_2021, TP_PRESENCA_CH_1_2021, TP_PRESENCA_CH_2_2021]

total_TP_PRESENCA_CH = TP_PRESENCA_CH_0_2020, TP_PRESENCA_CH_1_2020, TP_PRESENCA_CH_2_2020, TP_PRESENCA_CH_0_2021, TP_PRESENCA_CH_1_2021, TP_PRESENCA_CH_2_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_TP_PRESENCA_CH, align='center', color=['blue', 'blue', 'blue', 'red', 'red', 'red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes tipo de presença na prova de ciências humanas")
plt.ylabel("Tipo de presença na prova")
# Out:
# Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2021: 19615
# Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2021: 47817
# Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2021: 69
#
# Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2020: 60673
# Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2020: 56152
# Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2020: 107
# Text(0, 0.5, 'Tipo de presença na prova')

# %%
# Histograma projetando a presença de participantes na prova de ciencias humanas
print(planilha2020.TP_PRESENCA_CH.hist())
print(planilha2021.TP_PRESENCA_CH.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 16 - Presença na prova linguagens e codigos 2020 e 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['TP_PRESENCA_LC'] == 0)])
#display(planilha2021.loc[(planilha2021['TP_PRESENCA_LC'] == 1)])
#display(planilha2021.loc[(planilha2021['TP_PRESENCA_LC'] == 2)])

#display(planilha2020.loc[(planilha2020['TP_PRESENCA_LC'] == 0)])
#display(planilha2020.loc[(planilha2020['TP_PRESENCA_LC'] == 1)])
#display(planilha2020.loc[(planilha2020['TP_PRESENCA_LC'] == 2)])

TP_PRESENCA_LC_0_2021 = 19615
TP_PRESENCA_LC_1_2021 = 47817
TP_PRESENCA_LC_2_2021 = 69

TP_PRESENCA_LC_0_2020 = 60673
TP_PRESENCA_LC_1_2020 = 56152
TP_PRESENCA_LC_2_2020 = 107

print('Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2021:', TP_PRESENCA_LC_0_2021)
print('Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2021:', TP_PRESENCA_LC_1_2021)
print('Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2021:', TP_PRESENCA_LC_2_2021, '\n')

print('Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2020:', TP_PRESENCA_LC_0_2020)
print('Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2020:', TP_PRESENCA_LC_1_2020)
print('Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2020:', TP_PRESENCA_LC_2_2020, '\n')

# Printando grafico de barras horizontal
x = ['0 (faltou à prova) 2020', '1 (presente na prova) 2020', '2 (eliminado na prova) 2020', '0 (faltou à prova) 2021', '1 (presente na prova) 2021', '2 (eliminado na prova) 2021']
y = [TP_PRESENCA_LC_0_2020, TP_PRESENCA_LC_1_2020, TP_PRESENCA_LC_2_2020, TP_PRESENCA_LC_0_2021, TP_PRESENCA_LC_1_2021, TP_PRESENCA_LC_2_2021]

total_TP_PRESENCA_LC = TP_PRESENCA_LC_0_2020, TP_PRESENCA_LC_1_2020, TP_PRESENCA_LC_2_2020, TP_PRESENCA_LC_0_2021, TP_PRESENCA_LC_1_2021, TP_PRESENCA_LC_2_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_TP_PRESENCA_LC, align='center', color=['blue', 'blue', 'blue', 'red', 'red', 'red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes tipo de presença na prova de linguagens e codigos")
plt.ylabel("Tipo de presença na prova")
# Out:
# Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2021: 19615
# Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2021: 47817
# Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2021: 69
#
# Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2020: 60673
# Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2020: 56152
# Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2020: 107
# Text(0, 0.5, 'Tipo de presença na prova')

# %%
# Histograma projetando a presença de participantes na prova de linguagens e codigos 
print(planilha2020.TP_PRESENCA_LC.hist())
print(planilha2021.TP_PRESENCA_LC.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 17 - Presença na prova matematica 2020 e 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['TP_PRESENCA_MT'] == 0)])
#display(planilha2021.loc[(planilha2021['TP_PRESENCA_MT'] == 1)])
#display(planilha2021.loc[(planilha2021['TP_PRESENCA_MT'] == 2)])

#display(planilha2020.loc[(planilha2020['TP_PRESENCA_MT'] == 0)])
#display(planilha2020.loc[(planilha2020['TP_PRESENCA_MT'] == 1)])
#display(planilha2020.loc[(planilha2020['TP_PRESENCA_MT'] == 2)])

TP_PRESENCA_MT_0_2021 = 22319
TP_PRESENCA_MT_1_2021 = 45160
TP_PRESENCA_MT_2_2021 = 22

TP_PRESENCA_MT_0_2020 = 63922
TP_PRESENCA_MT_1_2020 = 52987
TP_PRESENCA_MT_2_2020 = 23

print('Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2021:', TP_PRESENCA_MT_0_2021)
print('Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2021:', TP_PRESENCA_MT_1_2021)
print('Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2021:', TP_PRESENCA_MT_2_2021, '\n')

print('Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2020:', TP_PRESENCA_MT_0_2020)
print('Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2020:', TP_PRESENCA_MT_1_2020)
print('Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2020:', TP_PRESENCA_MT_2_2020, '\n')

# Printando grafico de barras horizontal
x = ['0 (faltou à prova) 2020', '1 (presente na prova) 2020', '2 (eliminado na prova) 2020', '0 (faltou à prova) 2021', '1 (presente na prova) 2021', '2 (eliminado na prova) 2021']
y = [TP_PRESENCA_MT_0_2020, TP_PRESENCA_MT_1_2020, TP_PRESENCA_MT_2_2020, TP_PRESENCA_MT_0_2021, TP_PRESENCA_MT_1_2021, TP_PRESENCA_MT_2_2021]

total_TP_PRESENCA_MT = TP_PRESENCA_MT_0_2020, TP_PRESENCA_MT_1_2020, TP_PRESENCA_MT_2_2020, TP_PRESENCA_MT_0_2021, TP_PRESENCA_MT_1_2021, TP_PRESENCA_MT_2_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_TP_PRESENCA_MT, align='center', color=['blue', 'blue', 'blue', 'red', 'red', 'red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes tipo de presença na prova de matematica")
plt.ylabel("Tipo de presença na prova")
# Out:
# Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2021: 22319
# Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2021: 45160
# Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2021: 22
#
# Numero total de participantes tipo 0 (faltou à prova) na planilha Microdados Enem 2020: 63922
# Numero total de participantes tipo 1 (presente na prova) na planilha Microdados Enem 2020: 52987
# Numero total de participantes tipo 2 (eliminado na prova) na planilha Microdados Enem 2020: 23
# Text(0, 0.5, 'Tipo de presença na prova')

# %%
# Histograma projetando a presença de participantes na prova de matematica
print(planilha2020.TP_PRESENCA_MT.hist())
print(planilha2021.TP_PRESENCA_MT.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 18 - Quantidade de participantes por nota na prova de ciencias da natureza 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['NU_NOTA_CN']<=1000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CN']<=2000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CN']<=3000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CN']<=4000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CN']<=5000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CN']<=6000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CN']<=7000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CN']<=8000)])

NU_NOTA_CN_1000_2021 = 4458
NU_NOTA_CN_2000_2021 = 0
NU_NOTA_CN_3000_2021 = 0
NU_NOTA_CN_4000_2021 = 3783
NU_NOTA_CN_5000_2021 = 16542
NU_NOTA_CN_6000_2021 = 13889
NU_NOTA_CN_7000_2021 = 5708
NU_NOTA_CN_8000_2021 = 765

print('Numero total de participantes que tiraram <= a 100 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021:', NU_NOTA_CN_1000_2021)
print('Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021:', NU_NOTA_CN_2000_2021)
print('Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021:', NU_NOTA_CN_3000_2021)
print('Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021:', NU_NOTA_CN_4000_2021)
print('Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021:', NU_NOTA_CN_5000_2021)
print('Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021:', NU_NOTA_CN_6000_2021)
print('Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021:', NU_NOTA_CN_7000_2021)
print('Numero total de participantes que tiraram 800 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021:', NU_NOTA_CN_8000_2021, '\n')

# Printando grafico de barras horizontal
x = ['<= a 100 em 2021', '<= a 200 em 2021', '<= a 300 em 2021', '<= a 400 em 2021', '<= a 500 em 2021', '<= a 600 em 2021', '<= a 700 em 2021', '<= a 800 em 2021']
y = [NU_NOTA_CN_1000_2021, NU_NOTA_CN_2000_2021, NU_NOTA_CN_3000_2021, NU_NOTA_CN_4000_2021, NU_NOTA_CN_5000_2021, NU_NOTA_CN_6000_2021, NU_NOTA_CN_7000_2021, NU_NOTA_CN_8000_2021]

total_NU_NOTA_CN_2021 = NU_NOTA_CN_1000_2021, NU_NOTA_CN_2000_2021, NU_NOTA_CN_3000_2021, NU_NOTA_CN_4000_2021, NU_NOTA_CN_5000_2021, NU_NOTA_CN_6000_2021, NU_NOTA_CN_7000_2021, NU_NOTA_CN_8000_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_NU_NOTA_CN_2021, align='center', color=['red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por nota na prova de ciencias da natureza 2021")
plt.ylabel("Nota participante prova de ciencias da natureza")
# Out:
# Numero total de participantes que tiraram <= a 100 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021: 4458
# Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021: 0
# Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021: 0
# Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021: 3783
# Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021: 16542
# Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de ciencias da natureza na planilha Microdados Enem 2021: 13889
# ...

# %%
#---------------------------------- Grafico 19 - Quantidade de participantes por nota na prova de ciências da natureza 2020 ----------------------------------

#display(planilha2020.loc[(planilha2020['NU_NOTA_CN']<=1000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CN']<=2000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CN']<=3000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CN']<=4000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CN']<=5000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CN']<=6000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CN']<=7000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CN']<=8000)])

NU_NOTA_CN_1000_2020 = 5256
NU_NOTA_CN_2000_2020 = 0
NU_NOTA_CN_3000_2020 = 0
NU_NOTA_CN_4000_2020 = 5312
NU_NOTA_CN_5000_2020 = 18665
NU_NOTA_CN_6000_2020 = 17328
NU_NOTA_CN_7000_2020 = 5939
NU_NOTA_CN_8000_2020 = 482

print('Numero total de participantes que tiraram <= a 100 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020:', NU_NOTA_CN_1000_2020)
print('Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020:', NU_NOTA_CN_2000_2020)
print('Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020:', NU_NOTA_CN_3000_2020)
print('Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020:', NU_NOTA_CN_4000_2020)
print('Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020:', NU_NOTA_CN_5000_2020)
print('Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020:', NU_NOTA_CN_6000_2020)
print('Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020:', NU_NOTA_CN_7000_2020)
print('Numero total de participantes que tiraram 800 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020:', NU_NOTA_CN_8000_2020, '\n')

# Printando grafico de barras horizontal
x = ['<= a 100 em 2020', '<= a 200 em 2020', '<= a 300 em 2020', '<= a 400 em 2020', '<= a 500 em 2020', '<= a 600 em 2020', '<= a 700 em 2020', '<= a 800 em 2020']
y = [NU_NOTA_CN_1000_2020, NU_NOTA_CN_2000_2020, NU_NOTA_CN_3000_2020, NU_NOTA_CN_4000_2020, NU_NOTA_CN_5000_2020, NU_NOTA_CN_6000_2020, NU_NOTA_CN_7000_2020, NU_NOTA_CN_8000_2020]

total_NU_NOTA_CN_2020 = NU_NOTA_CN_1000_2020, NU_NOTA_CN_2000_2020, NU_NOTA_CN_3000_2020, NU_NOTA_CN_4000_2020, NU_NOTA_CN_5000_2020, NU_NOTA_CN_6000_2020, NU_NOTA_CN_7000_2020, NU_NOTA_CN_8000_2020

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_NU_NOTA_CN_2020, align='center', color=['blue'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por nota na prova de ciencias da natureza")
plt.ylabel("Nota participante prova de ciencias da natureza")
# Out:
# Numero total de participantes que tiraram <= a 100 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020: 5256
# Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020: 0
# Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020: 0
# Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020: 5312
# Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020: 18665
# Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de ciencias da natureza na planilha Microdados Enem 2020: 17328
# ...

# %%
# Histograma projetando a presença de participantes na prova de ciencias da natureza
print(planilha2020.NU_NOTA_CN.hist())
print(planilha2021.NU_NOTA_CN.hist())
print(planilha2020.NU_NOTA_REDACAO.median())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)
# 580.0

# %%
#---------------------------------- Grafico 20 - Quantidade de participantes por nota na prova de ciencias humanas 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['NU_NOTA_CH']<=1000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CH']<=2000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CH']<=3000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CH']<=4000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CH']<=5000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CH']<=6000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CH']<=7000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_CH']<=8000)])

NU_NOTA_CH_1000_2021 = 4873
NU_NOTA_CH_2000_2021 = 0
NU_NOTA_CH_3000_2021 = 0
NU_NOTA_CH_4000_2021 = 32775
NU_NOTA_CH_5000_2021 = 11216 
NU_NOTA_CH_6000_2021 = 15273 
NU_NOTA_CH_7000_2021 = 10746 
NU_NOTA_CH_8000_2021 = 1909 

print('Numero total de participantes que tiraram <= a 100 na nota da prova de ciencias humanas na planilha Microdados Enem 2021:', NU_NOTA_CH_1000_2021)
print('Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de ciencias humanas na planilha Microdados Enem 2021:', NU_NOTA_CH_2000_2021)
print('Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de ciencias humanas na planilha Microdados Enem 2021:', NU_NOTA_CH_3000_2021)
print('Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de ciencias humanas na planilha Microdados Enem 2021:', NU_NOTA_CH_4000_2021)
print('Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de ciencias humanas na planilha Microdados Enem 2021:', NU_NOTA_CH_5000_2021)
print('Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de ciencias humanas na planilha Microdados Enem 2021:', NU_NOTA_CH_6000_2021)
print('Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de ciencias humanas na planilha Microdados Enem 2021:', NU_NOTA_CH_7000_2021)
print('Numero total de participantes que tiraram 800 na nota da prova de ciencias humanas na planilha Microdados Enem 2021:', NU_NOTA_CH_8000_2021, '\n')


# Printando grafico de barras horizontal
x = ['<= a 100 em 2021', '<= a 200 em 2021', '<= a 300 em 2021', '<= a 400 em 2021', '<= a 500 em 2021', '<= a 600 em 2021', '<= a 700 em 2021', '<= a 800 em 2021']
y = [4873, 0, 0, 32775, 11216, 15273, 10746, 1909]
total_NU_NOTA_CH_2021 = NU_NOTA_CH_1000_2021, NU_NOTA_CH_2000_2021, NU_NOTA_CH_3000_2021, NU_NOTA_CH_4000_2021, NU_NOTA_CH_5000_2021, NU_NOTA_CH_6000_2021, NU_NOTA_CH_7000_2021, NU_NOTA_CH_8000_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_NU_NOTA_CH_2021, align='center', color=['red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por nota na prova de ciencias humanas")
plt.ylabel("Nota participante prova de ciencias humanas")
# Out:
# Numero total de participantes que tiraram <= a 100 na nota da prova de ciencias humanas na planilha Microdados Enem 2021: 4873
# Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de ciencias humanas na planilha Microdados Enem 2021: 0
# Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de ciencias humanas na planilha Microdados Enem 2021: 0
# Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de ciencias humanas na planilha Microdados Enem 2021: 32775
# Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de ciencias humanas na planilha Microdados Enem 2021: 11216
# Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de ciencias humanas na planilha Microdados Enem 2021: 15273
# Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de ciencias humanas na planilha Microdados Enem 2021: 10746
# ...

# %%
#---------------------------------- Grafico 20 - Quantidade de participantes por nota na prova de ciencias humanas 2020 ----------------------------------

#display(planilha2020.loc[(planilha2020['NU_NOTA_CH']<=1000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CH']<=2000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CH']<=3000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CH']<=4000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CH']<=5000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CH']<=6000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CH']<=7000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_CH']<=8000)])

NU_NOTA_CH_1000_2020 = 5256
NU_NOTA_CH_2000_2020 = 0
NU_NOTA_CH_3000_2020 = 0
NU_NOTA_CH_4000_2020 = 5312
NU_NOTA_CH_5000_2020 = 18665
NU_NOTA_CH_6000_2020 = 17328
NU_NOTA_CH_7000_2020 = 5939
NU_NOTA_CH_8000_2020 = 482

print('Numero total de participantes que tiraram <= a 100 na nota da prova de ciencias humanas na planilha Microdados Enem 2020:', NU_NOTA_CH_1000_2020)
print('Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de ciencias humanas na planilha Microdados Enem 2020:', NU_NOTA_CH_2000_2020)
print('Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de ciencias humanas na planilha Microdados Enem 2020:', NU_NOTA_CH_3000_2020)
print('Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de ciencias humanas na planilha Microdados Enem 2020:', NU_NOTA_CH_4000_2020)
print('Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de ciencias humanas na planilha Microdados Enem 2020:', NU_NOTA_CH_5000_2020)
print('Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de ciencias humanas na planilha Microdados Enem 2020:', NU_NOTA_CH_6000_2020)
print('Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de ciencias humanas na planilha Microdados Enem 2020:', NU_NOTA_CH_7000_2020)
print('Numero total de participantes que tiraram 800 na nota da prova de ciencias humanas na planilha Microdados Enem 2020:', NU_NOTA_CH_8000_2020, '\n')


# Printando grafico de barras horizontal
x = ['<= a 100 em 2020', '<= a 200 em 2020', '<= a 300 em 2020', '<= a 400 em 2020', '<= a 500 em 2020', '<= a 600 em 2020', '<= a 700 em 2020', '<= a 800 em 2020']
y = [5256, 0, 0, 5312, 18665, 17328, 5939, 482]
total_NU_NOTA_CH_2020 = NU_NOTA_CH_1000_2020, NU_NOTA_CH_2000_2020, NU_NOTA_CH_3000_2020, NU_NOTA_CH_4000_2020, NU_NOTA_CH_5000_2020, NU_NOTA_CH_6000_2020, NU_NOTA_CH_7000_2020, NU_NOTA_CH_8000_2020

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_NU_NOTA_CH_2020, align='center', color=['blue'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por nota na prova de ciencias humanas")
plt.ylabel("Nota participante prova de ciencias humanas")
# Out:
# Numero total de participantes que tiraram <= a 100 na nota da prova de ciencias humanas na planilha Microdados Enem 2020: 5256
# Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de ciencias humanas na planilha Microdados Enem 2020: 0
# Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de ciencias humanas na planilha Microdados Enem 2020: 0
# Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de ciencias humanas na planilha Microdados Enem 2020: 5312
# Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de ciencias humanas na planilha Microdados Enem 2020: 18665
# Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de ciencias humanas na planilha Microdados Enem 2020: 17328
# Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de ciencias humanas na planilha Microdados Enem 2020: 5939
# ...

# %%
# Histograma projetando a presença de participantes na prova de ciencias humanas
print(planilha2020.NU_NOTA_CH.hist())
print(planilha2021.NU_NOTA_CH.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 21 - Quantidade de participantes por nota na prova de linguagens e codigos ----------------------------------

#display(planilha2021.loc[(planilha2021['NU_NOTA_LC']<=1000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_LC']<=2000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_LC']<=3000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_LC']<=4000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_LC']<=5000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_LC']<=6000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_LC']<=7000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_LC']<=8000)])

NU_NOTA_LC_1000_2021 = 4795  
NU_NOTA_LC_2000_2021 = 0
NU_NOTA_LC_3000_2021 = 0
NU_NOTA_LC_4000_2021 = 3177
NU_NOTA_LC_5000_2021 = 12828
NU_NOTA_LC_6000_2021 = 19779
NU_NOTA_LC_7000_2021 = 7004
NU_NOTA_LC_8000_2021 = 234

print('Numero total de participantes que tiraram <= a 100 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021:', NU_NOTA_LC_1000_2021)
print('Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021:', NU_NOTA_LC_2000_2021)
print('Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021:', NU_NOTA_LC_3000_2021)
print('Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021:', NU_NOTA_LC_4000_2021)
print('Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021:', NU_NOTA_LC_5000_2021)
print('Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021:', NU_NOTA_LC_6000_2021)
print('Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021:', NU_NOTA_LC_7000_2021)
print('Numero total de participantes que tiraram 800 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021:', NU_NOTA_LC_8000_2021, '\n')

# Printando grafico de barras horizontal
x = ['<= a 100 em 2021', '<= a 200 em 2021', '<= a 300 em 2021', '<= a 400 em 2021', '<= a 500 em 2021', '<= a 600 em 2021', '<= a 700 em 2021', '<= a 800 em 2021']
y = [NU_NOTA_LC_1000_2021, NU_NOTA_LC_2000_2021, NU_NOTA_LC_3000_2021, NU_NOTA_LC_4000_2021, NU_NOTA_LC_5000_2021, NU_NOTA_LC_6000_2021, NU_NOTA_LC_7000_2021, NU_NOTA_LC_8000_2021]

total_NU_NOTA_LC_2021 = NU_NOTA_LC_1000_2021, NU_NOTA_LC_2000_2021, NU_NOTA_LC_3000_2021, NU_NOTA_LC_4000_2021, NU_NOTA_LC_5000_2021, NU_NOTA_LC_6000_2021, NU_NOTA_LC_7000_2021, NU_NOTA_LC_8000_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_NU_NOTA_LC_2021, align='center', color=['red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por nota na prova de linguagens e codigos")
plt.ylabel("Nota participante prova de linguagens e codigos")
# Out:
# Numero total de participantes que tiraram <= a 100 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021: 4795
# Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021: 0
# Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021: 0
# Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021: 3177
# Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021: 12828
# Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de linguagens e codigos na planilha Microdados Enem 2021: 19779
# ...

# %%
#---------------------------------- Grafico 22 - Quantidade de participantes por nota na prova de linguagens e codigos 2020 ----------------------------------

#display(planilha2020.loc[(planilha2020['NU_NOTA_LC']<=1000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_LC']<=2000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_LC']<=3000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_LC']<=4000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_LC']<=5000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_LC']<=6000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_LC']<=7000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_LC']<=8000)])

NU_NOTA_LC_1000_2020 = 5639 
NU_NOTA_LC_2000_2020 = 0
NU_NOTA_LC_3000_2020 = 0
NU_NOTA_LC_4000_2020 = 2078
NU_NOTA_LC_5000_2020 = 11815
NU_NOTA_LC_6000_2020 = 26249
NU_NOTA_LC_7000_2020 = 10209
NU_NOTA_LC_8000_2020 = 162

print('Numero total de participantes que tiraram <= a 100 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020:', NU_NOTA_LC_1000_2020)
print('Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020:', NU_NOTA_LC_1000_2020)
print('Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020:', NU_NOTA_LC_1000_2020)
print('Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020:', NU_NOTA_LC_1000_2020)
print('Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020:', NU_NOTA_LC_1000_2020)
print('Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020:', NU_NOTA_LC_1000_2020)
print('Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020:', NU_NOTA_LC_1000_2020)
print('Numero total de participantes que tiraram 800 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020:', NU_NOTA_LC_1000_2020, '\n')

# Printando grafico de barras horizontal
x = ['<= a 100 em 2020', '<= a 200 em 2020', '<= a 300 em 2020', '<= a 400 em 2020', '<= a 500 em 2020', '<= a 600 em 2020', '<= a 700 em 2020', '<= a 800 em 2020']
y = [NU_NOTA_LC_1000_2020, NU_NOTA_LC_2000_2020, NU_NOTA_LC_3000_2020, NU_NOTA_LC_4000_2020, NU_NOTA_LC_5000_2020, NU_NOTA_LC_6000_2020, NU_NOTA_LC_7000_2020, NU_NOTA_LC_8000_2020]

total_NU_NOTA_LC_2020 = NU_NOTA_LC_1000_2020, NU_NOTA_LC_2000_2020, NU_NOTA_LC_3000_2020, NU_NOTA_LC_4000_2020, NU_NOTA_LC_5000_2020, NU_NOTA_LC_6000_2020, NU_NOTA_LC_7000_2020, NU_NOTA_LC_8000_2020

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_NU_NOTA_LC_2020, align='center', color=['blue'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por nota na prova de linguagens e codigos")
plt.ylabel("Nota participante prova de linguagens e codigos")
# Out:
# Numero total de participantes que tiraram <= a 100 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020: 5639
# Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020: 5639
# Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020: 5639
# Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020: 5639
# Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020: 5639
# Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de linguagens e codigos na planilha Microdados Enem 2020: 5639
# ...

# %%
# Histograma projetando a presença de participantes na prova de linguagens e codigos
print(planilha2020.NU_NOTA_LC.hist())
print(planilha2021.NU_NOTA_LC.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 23 - Quantidade de participantes por nota na prova de matematica 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['NU_NOTA_MT']<=1000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_MT']<=2000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_MT']<=3000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_MT']<=4000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_MT']<=5000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_MT']<=6000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_MT']<=7000)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_MT']<=8000)])

NU_NOTA_MT_1000_2021 = 4438   
NU_NOTA_MT_2000_2021 = 0
NU_NOTA_MT_3000_2021 = 0
NU_NOTA_MT_4000_2021 = 2831
NU_NOTA_MT_5000_2021 = 13360
NU_NOTA_MT_6000_2021 = 10574
NU_NOTA_MT_7000_2021 = 8787
NU_NOTA_MT_8000_2021 = 4079

print('Numero total de participantes que tiraram <= a 100 na nota da prova de matematica na planilha Microdados Enem 2021:', NU_NOTA_MT_1000_2021)
print('Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de matematica na planilha Microdados Enem 2021:', NU_NOTA_MT_2000_2021)
print('Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de matematica na planilha Microdados Enem 2021:', NU_NOTA_MT_3000_2021)
print('Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de matematica na planilha Microdados Enem 2021:', NU_NOTA_MT_4000_2021)
print('Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de matematica na planilha Microdados Enem 2021:', NU_NOTA_MT_5000_2021)
print('Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de matematica na planilha Microdados Enem 2021:', NU_NOTA_MT_6000_2021)
print('Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de matematica na planilha Microdados Enem 2021:', NU_NOTA_MT_7000_2021)
print('Numero total de participantes que tiraram 800 na nota da prova de matematica na planilha Microdados Enem 2021:', NU_NOTA_MT_8000_2021, '\n')

# Printando grafico de barras horizontal
x = ['<= a 100 em 2021', '<= a 200 em 2021', '<= a 300 em 2021', '<= a 400 em 2021', '<= a 500 em 2021', '<= a 600 em 2021', '<= a 700 em 2021', '<= a 800 em 2021']
y = [NU_NOTA_MT_1000_2021, NU_NOTA_MT_2000_2021, NU_NOTA_MT_3000_2021, NU_NOTA_MT_4000_2021, NU_NOTA_MT_5000_2021, NU_NOTA_MT_6000_2021, NU_NOTA_MT_7000_2021, NU_NOTA_MT_8000_2021]

total_NU_NOTA_MT_2021 = NU_NOTA_MT_1000_2021, NU_NOTA_MT_2000_2021, NU_NOTA_MT_3000_2021, NU_NOTA_MT_4000_2021, NU_NOTA_MT_5000_2021, NU_NOTA_MT_6000_2021, NU_NOTA_MT_7000_2021, NU_NOTA_MT_8000_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_NU_NOTA_MT_2021, align='center', color=['red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por nota na prova de matematica")
plt.ylabel("Nota participante prova de matematica")
# Out:
# Numero total de participantes que tiraram <= a 100 na nota da prova de matematica na planilha Microdados Enem 2021: 4438
# Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de matematica na planilha Microdados Enem 2021: 0
# Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de matematica na planilha Microdados Enem 2021: 0
# Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de matematica na planilha Microdados Enem 2021: 2831
# Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de matematica na planilha Microdados Enem 2021: 13360
# Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de matematica na planilha Microdados Enem 2021: 10574
# Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de matematica na planilha Microdados Enem 2021: 8787
# ...

# %%
#---------------------------------- Grafico 24 - Quantidade de participantes por nota na prova de matematica 2020 ----------------------------------

#display(planilha2020.loc[(planilha2020['NU_NOTA_MT']<=1000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_MT']<=2000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_MT']<=3000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_MT']<=4000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_MT']<=5000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_MT']<=6000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_MT']<=7000)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_MT']<=8000)])

NU_NOTA_MT_1000_2020 = 5428 
NU_NOTA_MT_2000_2020 = 0
NU_NOTA_MT_3000_2020 = 0
NU_NOTA_MT_4000_2020 = 6904
NU_NOTA_MT_5000_2020 = 14366
NU_NOTA_MT_6000_2020 = 11934
NU_NOTA_MT_7000_2020 = 9345
NU_NOTA_MT_8000_2020 = 3749

print('Numero total de participantes que tiraram <= a 100 na nota da prova de matematica na planilha Microdados Enem 2020:', NU_NOTA_MT_1000_2020)
print('Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de matematica na planilha Microdados Enem 2020:', NU_NOTA_MT_1000_2020)
print('Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de matematica na planilha Microdados Enem 2020:', NU_NOTA_MT_1000_2020)
print('Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de matematica na planilha Microdados Enem 2020:', NU_NOTA_MT_1000_2020)
print('Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de matematica na planilha Microdados Enem 2020:', NU_NOTA_MT_1000_2020)
print('Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de matematica na planilha Microdados Enem 2020:', NU_NOTA_MT_1000_2020)
print('Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de matematica na planilha Microdados Enem 2020:', NU_NOTA_MT_1000_2020)
print('Numero total de participantes que tiraram 800 na nota da prova de matematica na planilha Microdados Enem 2020:', NU_NOTA_MT_1000_2020, '\n')

# Printando grafico de barras horizontal
x = ['<= a 100 em 2020', '<= a 200 em 2020', '<= a 300 em 2020', '<= a 400 em 2020', '<= a 500 em 2020', '<= a 600 em 2020', '<= a 700 em 2020', '<= a 800 em 2020']
y = [NU_NOTA_MT_1000_2020, NU_NOTA_MT_2000_2020, NU_NOTA_MT_3000_2020, NU_NOTA_MT_4000_2020, NU_NOTA_MT_5000_2020, NU_NOTA_MT_6000_2020, NU_NOTA_MT_7000_2020, NU_NOTA_MT_8000_2020]

total_NU_NOTA_MT_2020 = NU_NOTA_MT_1000_2020, NU_NOTA_MT_2000_2020, NU_NOTA_MT_3000_2020, NU_NOTA_MT_4000_2020, NU_NOTA_MT_5000_2020, NU_NOTA_MT_6000_2020, NU_NOTA_MT_7000_2020, NU_NOTA_MT_8000_2020

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_NU_NOTA_MT_2020, align='center', color=['blue'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por nota na prova de matematica")
plt.ylabel("Nota participante prova de matematica")
# Out:
# Numero total de participantes que tiraram <= a 100 na nota da prova de matematica na planilha Microdados Enem 2020: 5428
# Numero total de participantes que tiraram mais que 100 e <= a 200 na nota da prova de matematica na planilha Microdados Enem 2020: 5428
# Numero total de participantes que tiraram mais que 200 e <= a 300 na nota da prova de matematica na planilha Microdados Enem 2020: 5428
# Numero total de participantes que tiraram mais que 300 e <= a 400 na nota da prova de matematica na planilha Microdados Enem 2020: 5428
# Numero total de participantes que tiraram mais que 400 e <= a 500 na nota da prova de matematica na planilha Microdados Enem 2020: 5428
# Numero total de participantes que tiraram mais que 500 e <= a 600 na nota da prova de matematica na planilha Microdados Enem 2020: 5428
# Numero total de participantes que tiraram mais que 600 e <= a 700 na nota da prova de matematica na planilha Microdados Enem 2020: 5428
# ...

# %%
# Histograma projetando a presença de participantes na prova de matematica
print(planilha2020.NU_NOTA_MT.hist())
print(planilha2021.NU_NOTA_MT.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 25 - Quantidade de participantes por nota na prova de redacao 2021 ----------------------------------

#display(planilha2021.loc[(planilha2021['NU_NOTA_REDACAO'] <= 100)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_REDACAO'] <= 200)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_REDACAO'] <= 300)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_REDACAO'] <= 400)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_REDACAO'] <= 500)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_REDACAO'] <= 600)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_REDACAO'] <= 700)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_REDACAO'] <= 800)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_REDACAO'] <= 900)])
#display(planilha2021.loc[(planilha2021['NU_NOTA_REDACAO'] <= 1000)])

NU_NOTA_REDACAO_100_2021 = 1376 
NU_NOTA_REDACAO_200_2021 = 16  
NU_NOTA_REDACAO_300_2021 = 284 
NU_NOTA_REDACAO_400_2021 = 1979   
NU_NOTA_REDACAO_500_2021 = 5989 
NU_NOTA_REDACAO_600_2021 = 13938  
NU_NOTA_REDACAO_700_2021 = 10183   
NU_NOTA_REDACAO_800_2021 = 6359  
NU_NOTA_REDACAO_900_2021 = 5408  
NU_NOTA_REDACAO_1000_2021 = 2285  

print('Numero total de participantes que tiraram <= a 100 na nota da prova de redacao na planilha Microdados Enem 2021:', NU_NOTA_REDACAO_100_2021)
print('Numero total de participantes que tiraram > que 100 e <= a 200 na nota da prova de redacao na planilha Microdados Enem 2021:', NU_NOTA_REDACAO_200_2021)
print('Numero total de participantes que tiraram > que 200 e <= a 300 na nota da prova de redacao na planilha Microdados Enem 2021:', NU_NOTA_REDACAO_300_2021)
print('Numero total de participantes que tiraram > que 300 e <= a 400 na nota da prova de redacao na planilha Microdados Enem 2021:', NU_NOTA_REDACAO_400_2021)
print('Numero total de participantes que tiraram > que 400 e <= a 500 na nota da prova de redacao na planilha Microdados Enem 2021:', NU_NOTA_REDACAO_500_2021)
print('Numero total de participantes que tiraram > que 500 e <= a 600 na nota da prova de redacao na planilha Microdados Enem 2021:', NU_NOTA_REDACAO_600_2021)
print('Numero total de participantes que tiraram > que 600 e <= a 700 na nota da prova de redacao na planilha Microdados Enem 2021:', NU_NOTA_REDACAO_700_2021)
print('Numero total de participantes que tiraram > que 700 e <= a 800 na nota da prova de redacao na planilha Microdados Enem 2021:', NU_NOTA_REDACAO_800_2021)
print('Numero total de participantes que tiraram > que 800 e <= a 900 na nota da prova de redacao na planilha Microdados Enem 2021:', NU_NOTA_REDACAO_900_2021)
print('Numero total de participantes que tiraram > que 900 e <= a 1000 na nota da prova de redacao na planilha Microdados Enem 2021:', NU_NOTA_REDACAO_1000_2021, '\n')

# Printando grafico de barras horizontal
x = ['<= a 100 em 2021', '<= a 200 em 2021', '<= a 300 em 2021', '<= a 400 em 2021', '<= a 500 em 2021', '<= a 600 em 2021', '<= a 700 em 2021', '<= a 800 em 2021', '<= a 900 em 2021', '<= a 1000 em 2021']
y = [NU_NOTA_REDACAO_100_2021, NU_NOTA_REDACAO_200_2021, NU_NOTA_REDACAO_300_2021, NU_NOTA_REDACAO_400_2021, NU_NOTA_REDACAO_500_2021, NU_NOTA_REDACAO_600_2021, NU_NOTA_REDACAO_700_2021, NU_NOTA_REDACAO_800_2021, NU_NOTA_REDACAO_900_2021, NU_NOTA_REDACAO_1000_2021]

total_NU_NOTA_REDACAO_2021 = NU_NOTA_REDACAO_100_2021, NU_NOTA_REDACAO_200_2021, NU_NOTA_REDACAO_300_2021, NU_NOTA_REDACAO_400_2021, NU_NOTA_REDACAO_500_2021, NU_NOTA_REDACAO_600_2021, NU_NOTA_REDACAO_700_2021, NU_NOTA_REDACAO_800_2021, NU_NOTA_REDACAO_900_2021, NU_NOTA_REDACAO_1000_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_NU_NOTA_REDACAO_2021, align='center', color=['red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por nota na prova de redacao")
plt.ylabel("Nota participante prova de redacao")
# Out:
# Numero total de participantes que tiraram <= a 100 na nota da prova de redacao na planilha Microdados Enem 2021: 1376
# Numero total de participantes que tiraram > que 100 e <= a 200 na nota da prova de redacao na planilha Microdados Enem 2021: 16
# Numero total de participantes que tiraram > que 200 e <= a 300 na nota da prova de redacao na planilha Microdados Enem 2021: 284
# Numero total de participantes que tiraram > que 300 e <= a 400 na nota da prova de redacao na planilha Microdados Enem 2021: 1979
# Numero total de participantes que tiraram > que 400 e <= a 500 na nota da prova de redacao na planilha Microdados Enem 2021: 5989
# Numero total de participantes que tiraram > que 500 e <= a 600 na nota da prova de redacao na planilha Microdados Enem 2021: 13938
# Numero total de participantes que tiraram > que 600 e <= a 700 na nota da prova de redacao na planilha Microdados Enem 2021: 10183
# ...

# %%
#---------------------------------- Grafico 26 - Quantidade de participantes por nota na prova de redacao 2020 ----------------------------------

#display(planilha2020.loc[(planilha2020['NU_NOTA_REDACAO'] <= 100)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_REDACAO'] <= 200)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_REDACAO'] <= 300)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_REDACAO'] <= 400)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_REDACAO'] <= 500)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_REDACAO'] <= 600)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_REDACAO'] <= 700)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_REDACAO'] <= 800)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_REDACAO'] <= 900)])
#display(planilha2020.loc[(planilha2020['NU_NOTA_REDACAO'] <= 1000)])

NU_NOTA_REDACAO_100_2020 = 1364 
NU_NOTA_REDACAO_200_2020 = 73 
NU_NOTA_REDACAO_300_2020 = 1955
NU_NOTA_REDACAO_400_2020 = 8742
NU_NOTA_REDACAO_500_2020 = 6861
NU_NOTA_REDACAO_600_2020 = 15850
NU_NOTA_REDACAO_700_2020 = 9671 
NU_NOTA_REDACAO_800_2020 = 5667 
NU_NOTA_REDACAO_900_2020 = 4668 
NU_NOTA_REDACAO_1000_2020 = 2738 

print('Numero total de participantes que tiraram <= a 100 na nota da prova de redacao na planilha Microdados Enem 2020:', NU_NOTA_REDACAO_100_2020)
print('Numero total de participantes que tiraram > que 100 e <= a 200 na nota da prova de redacao na planilha Microdados Enem 2020:', NU_NOTA_REDACAO_200_2020)
print('Numero total de participantes que tiraram > que 200 e <= a 300 na nota da prova de redacao na planilha Microdados Enem 2020:', NU_NOTA_REDACAO_300_2020)
print('Numero total de participantes que tiraram > que 300 e <= a 400 na nota da prova de redacao na planilha Microdados Enem 2020:', NU_NOTA_REDACAO_400_2020)
print('Numero total de participantes que tiraram > que 400 e <= a 500 na nota da prova de redacao na planilha Microdados Enem 2020:', NU_NOTA_REDACAO_500_2020)
print('Numero total de participantes que tiraram > que 500 e <= a 600 na nota da prova de redacao na planilha Microdados Enem 2020:', NU_NOTA_REDACAO_600_2020)
print('Numero total de participantes que tiraram > que 600 e <= a 700 na nota da prova de redacao na planilha Microdados Enem 2020:', NU_NOTA_REDACAO_700_2020)
print('Numero total de participantes que tiraram > que 700 e <= a 800 na nota da prova de redacao na planilha Microdados Enem 2020:', NU_NOTA_REDACAO_800_2020)
print('Numero total de participantes que tiraram > que 800 e <= a 900 na nota da prova de redacao na planilha Microdados Enem 2020:', NU_NOTA_REDACAO_900_2020)
print('Numero total de participantes que tiraram > que 900 e <= a 1000 na nota da prova de redacao na planilha Microdados Enem 2020:', NU_NOTA_REDACAO_1000_2020, '\n')

# Printando grafico de barras horizontal
x = ['<= a 100 em 2020', '<= a 200 em 2020', '<= a 300 em 2020', '<= a 400 em 2020', '<= a 500 em 2020', '<= a 600 em 2020', '<= a 700 em 2020', '<= a 800 em 2020', '<= a 900 em 2020', '<= a 1000 em 2020']
y = [NU_NOTA_REDACAO_100_2020, NU_NOTA_REDACAO_200_2020, NU_NOTA_REDACAO_300_2020, NU_NOTA_REDACAO_400_2020, NU_NOTA_REDACAO_500_2020, NU_NOTA_REDACAO_600_2020, NU_NOTA_REDACAO_700_2020, NU_NOTA_REDACAO_800_2020, NU_NOTA_REDACAO_900_2020, NU_NOTA_REDACAO_1000_2020]

total_NU_NOTA_REDACAO_2020 = NU_NOTA_REDACAO_100_2020, NU_NOTA_REDACAO_200_2020, NU_NOTA_REDACAO_300_2020, NU_NOTA_REDACAO_400_2020, NU_NOTA_REDACAO_500_2020, NU_NOTA_REDACAO_600_2020, NU_NOTA_REDACAO_700_2020, NU_NOTA_REDACAO_800_2020, NU_NOTA_REDACAO_900_2020, NU_NOTA_REDACAO_1000_2020

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_NU_NOTA_REDACAO_2020, align='center', color=['blue'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por nota na prova de redacao")
plt.ylabel("Nota participante prova de redacao")
# Out:
# Numero total de participantes que tiraram <= a 100 na nota da prova de redacao na planilha Microdados Enem 2020: 1364
# Numero total de participantes que tiraram > que 100 e <= a 200 na nota da prova de redacao na planilha Microdados Enem 2020: 73
# Numero total de participantes que tiraram > que 200 e <= a 300 na nota da prova de redacao na planilha Microdados Enem 2020: 1955
# Numero total de participantes que tiraram > que 300 e <= a 400 na nota da prova de redacao na planilha Microdados Enem 2020: 8742
# Numero total de participantes que tiraram > que 400 e <= a 500 na nota da prova de redacao na planilha Microdados Enem 2020: 6861
# Numero total de participantes que tiraram > que 500 e <= a 600 na nota da prova de redacao na planilha Microdados Enem 2020: 15850
# Numero total de participantes que tiraram > que 600 e <= a 700 na nota da prova de redacao na planilha Microdados Enem 2020: 9671
# ...

# %%
# Histograma projetando a presença de participantes na prova de redacao
print(planilha2020.NU_NOTA_REDACAO.hist())
print(planilha2021.NU_NOTA_REDACAO.hist())
# Out:
# AxesSubplot(0.08,0.07;0.87x0.81)
# AxesSubplot(0.08,0.07;0.87x0.81)

# %%
#---------------------------------- Grafico 27 - media de notas por disciplina - 2021 ----------------------------------

media_CN = np.mean(planilha2021['NU_NOTA_CN']/10)
media_CH = np.mean(planilha2021['NU_NOTA_CH']/10)
media_LC = np.mean(planilha2021['NU_NOTA_LC']/10)
media_MT = np.mean(planilha2021['NU_NOTA_MT']/10)
media_REDACAO = np.mean(planilha2021['NU_NOTA_REDACAO'])

notas_medias={'Ciencias da natureza':media_CN,
              'Ciencias Humanas':media_CH,
              'Linguagens e Codigos': media_LC,
              'Matematica':media_MT,
              'Redacao':media_REDACAO}

lists = sorted(notas_medias.items()) 

x1, y1 = zip(*lists) 
plt.figure(figsize=(14,8))

plt.bar(x1, y1)
plt.title('Nota media por disciplina 2021')
plt.xlabel('Disciplina')
plt.ylabel('Nota')
plt.show()

# %%
#---------------------------------- Grafico 28 - media de notas por disciplina - 2020 ----------------------------------

media_CN = np.mean(planilha2020['NU_NOTA_CN']/10)
media_CH = np.mean(planilha2020['NU_NOTA_CH']/10)
media_LC = np.mean(planilha2020['NU_NOTA_LC']/10)
media_MT = np.mean(planilha2020['NU_NOTA_MT']/10)
media_REDACAO = np.mean(planilha2020['NU_NOTA_REDACAO'])

notas_medias={'Ciencias da natureza':media_CN,
              'Ciencias Humanas':media_CH,
              'Linguagens e Codigos': media_LC,
              'Matematica':media_MT,
              'Redacao':media_REDACAO}

lists = sorted(notas_medias.items()) 

x1, y1 = zip(*lists) 
plt.figure(figsize=(14,8))

plt.bar(x1, y1)
plt.title('Nota media por disciplina 2020')
plt.xlabel('Disciplina')
plt.ylabel('Nota')
plt.show()

# %% [markdown]
# # Análise gráfica com cruzamento de variáveis

# %%
colunas = ['TP_FAIXA_ETARIA','TP_SEXO','TP_COR_RACA','TP_ESCOLA', 'Q006', 'Q022','Q024','Q025','NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']
base2020 = pd.read_csv("./drive/MyDrive/trabalho_ia/data/MICRODADOS_ENEM_2020_DF.csv", encoding='latin-1', sep=';', usecols=colunas)
base2021 = pd.read_csv("./drive/MyDrive/trabalho_ia/data/MICRODADOS_ENEM_2021_DF.csv", encoding='latin-1', sep=';', usecols=colunas)

total_null = base2020.isnull().sum().sort_values(ascending = False)
total_null = base2021.isnull().sum().sort_values(ascending = False)

# Elimina as linhas com nota média NaN
base2020.dropna(inplace=True)
base2021.dropna(inplace=True)

base2020.info()
base2021.info()

print(len(base2020))
print(len(base2021))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51586 entries, 3 to 116919
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TP_FAIXA_ETARIA  51586 non-null  int64
#  1   TP_SEXO          51586 non-null  object
#  2   TP_COR_RACA      51586 non-null  int64
#  3   TP_ESCOLA        51586 non-null  int64
#  4   NU_NOTA_CN       51586 non-null  float64
#  5   NU_NOTA_CH       51586 non-null  float64
#  6   NU_NOTA_LC       51586 non-null  float64
#  7   NU_NOTA_MT       51586 non-null  float64
#  8   NU_NOTA_REDACAO  51586 non-null  float64
#  9   Q006             51586 non-null  object
#  10  Q022             51586 non-null  object
#  11  Q024             51586 non-null  object
#  12  Q025             51586 non-null  object
# dtypes: float64(5), int64(3), object(5)
# memory usage: 5.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45005 entries, 0 to 67499
# ...

# %%
# Criando a variável de média na tabela de 2021
base2021['NOTA_MEDIA'] = (
    (base2021['NU_NOTA_CN'] + base2021['NU_NOTA_CH'] + base2021['NU_NOTA_LC'] + base2021['NU_NOTA_MT'])/10 + 
    base2021['NU_NOTA_REDACAO']) /5

# %%
# Criando a variável de média na tabela de 2020
base2020['NOTA_MEDIA'] = (
    (base2020['NU_NOTA_CN'] + base2020['NU_NOTA_CH'] + base2020['NU_NOTA_LC'] + base2020['NU_NOTA_MT']) /10 + 
    base2020['NU_NOTA_REDACAO'] )/ 5

# %%
#---------------------------------- Grafico 29 - Mapa de correlação das variáveis numéricas - 2021 ----------------------------------
sns.set_style("whitegrid") 

sns.heatmap(base2021.corr(), annot=True, cmap="PiYG")
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
#---------------------------------- Grafico 30 - Mapa de correlação das variáveis numéricas - 2020 ----------------------------------
sns.heatmap(base2020.corr(), annot=True, cmap="PiYG")
plt.show()

# %%
#---------------------------------- Grafico 31 - media de notas por raça - 2021 ----------------------------------
base2021_TP_COR_RACA = pd.Series(base2021.TP_COR_RACA, dtype='category').cat.rename_categories({3:'Parda', 2:'Preta', 1:'Branca', 0:'Não Declarado', 4:'Amarela', 5:'Indígena', 6:'Não dispor'})

base2021['TP_COR_RACA_c'] = base2021_TP_COR_RACA
sns.boxplot(x = 'TP_COR_RACA_c', y = 'NOTA_MEDIA', data = base2021)
plt.title("Nota média por raça 2021")
plt.xlabel('Etnia')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
#---------------------------------- Grafico 32 - media de notas por raça - 2020 ----------------------------------
base2020_TP_COR_RACA = pd.Series(base2020.TP_COR_RACA, dtype='category').cat.rename_categories({3:'Parda', 2:'Preta', 1:'Branca', 0:'Não Declarado', 4:'Amarela', 5:'Indígena', 6:'Não dispor'})

base2020['TP_COR_RACA_c'] = base2020_TP_COR_RACA
sns.boxplot(x = 'TP_COR_RACA_c', y = 'NOTA_MEDIA', data = base2020)
plt.title("Nota média por raça 2020")
plt.xlabel('Etnia')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
#---------------------------------- Grafico 33 - media de notas por renda - 2021 ----------------------------------
sns.boxplot(x = 'Q006', y = 'NOTA_MEDIA', data = base2021,
           order=list(string.ascii_uppercase[:17]))
plt.title('Nota média por renda 2021')
plt.xlabel('Classe social')
plt.ylabel('Nota Média')
plt.show()

# %%
#---------------------------------- Grafico 34 - media de notas por raça - 2020 ---------------------------------- 
sns.boxplot(x = 'Q006', y = 'NOTA_MEDIA', data = base2020,
           order=list(string.ascii_uppercase[:17]))
plt.title('Nota média por renda 2020')
plt.xlabel('Classe social')
plt.ylabel('Nota Média')
plt.show()

# %%
#---------------------------------- Grafico 35 - media de notas por sexo - 2021 ----------------------------------
sns.boxplot(x = 'TP_SEXO', y = 'NOTA_MEDIA', data = base2021)
plt.title("Nota média por sexo 2021")
plt.xlabel('Sexo')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
#---------------------------------- Grafico 36 - media de notas por sexo - 2020 ----------------------------------
sns.boxplot(x = 'TP_SEXO', y = 'NOTA_MEDIA', data = base2020)
plt.title("Nota média por sexo 2020")
plt.xlabel('Sexo')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
sns.boxplot(x = 'TP_FAIXA_ETARIA', y = 'NOTA_MEDIA', data = base2020)
plt.title("Nota média por faixa etária 2020")
plt.xlabel('Faixa etária')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
sns.boxplot(x = 'TP_FAIXA_ETARIA', y = 'NOTA_MEDIA', data = base2021)
plt.title("Nota média por faixa etária 2021")
plt.xlabel('Faixa etária')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
base2020_TP_ESCOLA = pd.Series(base2020.TP_ESCOLA, dtype='category').cat.rename_categories({3:'Privada', 2:'Pública', 1:'Nao Respondeu'})

base2020['TP_ESCOLA_c'] = base2020_TP_ESCOLA
sns.boxplot(x = 'TP_ESCOLA_c', y = 'NOTA_MEDIA', data = base2020)
plt.title("Nota média por escola 2020")
plt.xlabel('Escola')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
base2021_TP_ESCOLA = pd.Series(base2021.TP_ESCOLA, dtype='category').cat.rename_categories({3:'Privada', 2:'Pública', 1:'Nao Respondeu'})

base2021['TP_ESCOLA_c'] = base2021_TP_ESCOLA
sns.boxplot(x = 'TP_ESCOLA_c', y = 'NOTA_MEDIA', data = base2021)
plt.title("Nota média por escola 2021")
plt.xlabel('Escola')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
duplicas = planilha2021.pivot_table(index = ['Q024'], aggfunc ='size')
print(duplicas)
# Out:
# Q024
# A    17301
# B    29786
# C    11037
# D     5645
# E     3732
# dtype: int64

# %%
  
Q022_A_2020 = 17301
Q022_B_2020 = 29786
Q022_C_2020 = 11037
Q022_D_2020 = 5645
Q022_E_2020 = 3732

Q022_A_2021 =  41196
Q022_B_2021 = 51099
Q022_C_2021 = 12537
Q022_D_2021 = 5280
Q022_E_2021 = 3058

# Printando grafico de barras horizontal
x = ['A (não) 2021', 'B (sim, um) 2021', 'C (sim, dois) 2021', 'D (sim, três) 2021', 'E (sim, quatro ou mais) 2021', 'A (não) 2020', 'B (sim, um) 2020', 'C (sim, dois) 2020', 'D (sim, três) 2020', 'E (sim, quatro ou mais) 2020']
y = [Q022_A_2020, Q022_B_2020, Q022_C_2020, Q022_D_2020, Q022_E_2020, Q022_A_2021, Q022_B_2021, Q022_C_2021, Q022_D_2021, Q022_E_2021]

total_Q022_A_B = Q022_A_2020, Q022_B_2020, Q022_C_2020, Q022_D_2020, Q022_E_2020, Q022_A_2021, Q022_B_2021, Q022_C_2021, Q022_D_2021, Q022_E_2021

plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, total_Q022_A_B, align='center', color=['blue', 'blue', 'blue', 'blue', 'blue', 'red', 'red', 'red', 'red', 'red'], edgecolor='black', linewidth="1") 
plt.xlabel("Quantidade de participantes por tipo de acesso a Computador")
plt.ylabel("Resposta participante para acesso a Computador")
# Out:
# Text(0, 0.5, 'Resposta participante para acesso a Computador')

# %%
base2021_Q025 = pd.Series(base2021.Q025, dtype='category').cat.rename_categories({'B':'Sim', 'A':'Não'})

base2021['Q025_c'] = base2021_Q025
sns.boxplot(x = 'Q025_c', y = 'NOTA_MEDIA', data = base2021)
plt.title("Nota média por acesso a internet 2021")
plt.xlabel('Acesso a internet')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
base2020_Q025 = pd.Series(base2020.Q025, dtype='category').cat.rename_categories({'B':'Sim', 'A':'Não'})

base2020['Q025_c'] = base2020_Q025
sns.boxplot(x = 'Q025_c', y = 'NOTA_MEDIA', data = base2020)
plt.title("Nota média por acesso a internet 2020")
plt.xlabel('Acesso a internet')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
sns.boxplot(x = 'Q024', y = 'NOTA_MEDIA', data = base2021)
plt.title("Nota média por Acesso a Computador 2021")
plt.xlabel('Acesso a Computador')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
sns.boxplot(x = 'Q024', y = 'NOTA_MEDIA', data = base2020)
plt.title("Nota média por Acesso a Computador 2020")
plt.xlabel('Acesso a Computador')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
sns.boxplot(x = 'Q022', y = 'NOTA_MEDIA', data = base2021)
plt.title("Nota média por Acesso a Celular 2021")
plt.xlabel('Acesso a Celular')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')

# %%
sns.boxplot(x = 'Q022', y = 'NOTA_MEDIA', data = base2020)
plt.title("Nota média por Acesso a Celular 2020")
plt.xlabel('Acesso a Celular')
plt.ylabel('Nota Média')
# Out:
# Text(0, 0.5, 'Nota Média')
