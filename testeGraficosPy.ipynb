# %% [markdown]
# <a href="https://colab.research.google.com/github/kingofrats04/Projeto_IA_DadosEnem/blob/main/testeGraficosPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conectando ao drive do projeto
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# Importando planilha do Excel
planilha2020 = pd.read_csv('./drive/MyDrive/trabalho_ia/data/MICRODADOS_ENEM_2020_DF.csv', sep=';' , encoding='latin-1')
planilha2021 = pd.read_csv("./drive/MyDrive/trabalho_ia/data/MICRODADOS_ENEM_2021_DF.csv", sep=';' , encoding='latin-1')

#---------------------------------- Grafico 1 ----------------------------------

# Printar total de participantes por ano
print('Numero total de participantes na planilha Microdados Enem 2020:', planilha2020.NU_PARTICIPANTES.max())
print('Numero total de participantes na planilha Microdados Enem 2021:', planilha2021.NU_PARTICIPANTES.max(), '\n')

num1 = planilha2020.NU_PARTICIPANTES.max()
num2 = planilha2021.NU_PARTICIPANTES.max()

# Printando grafico de barras horizontal
x = ['Planilha 2020', 'Planilha 2021']
y = [116932, 67501]

totalAlunos = num1, num2
plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, totalAlunos, align='center', color=['red', 'white'], edgecolor='black', linewidth="1") 
plt.xlabel("Total alunos por ano")
plt.ylabel("Planilhas")
# Out:
# Numero total de participante na planilha Microdados Enem 2020: 116932
# Numero total de participante na planilha Microdados Enem 2021: 67501
# Text(0, 0.5, 'Planilhas')

# %%
#---------------------------------- Grafico 2 ----------------------------------

#display(planilha2020.loc[(planilha2020['TP_SEXO']=='F')])
#display(planilha2020.loc[(planilha2020['TP_SEXO']=='M')])
#display(planilha2021.loc[(planilha2021['TP_SEXO']=='F')])
#display(planilha2021.loc[(planilha2021['TP_SEXO']=='M')])

#print(planilha2021.TP_SEXO.hist())

# Printar total de participantes por sexo
print('Numero total de participantes do sexo feminino na planilha Microdados Enem 2020: 70044')
print('Numero total de participantes do sexo masculino planilha Microdados Enem 2020: 46888\n')
print('Numero total de participantes do sexo feminino planilha Microdados Enem 2021: 41167')
print('Numero total de participantes do sexo masculino planilha Microdados Enem 2021: 26334\n')

numF2020 = 70044 
numM2020 = 46888

numF2021 = 41167
numM2021 = 26334


# Printando grafico de barras horizontal
x = ['Feminino 2020', 'Masculino 2020', 'Feminino 2021', 'Masculino 2021']
y = [70044, 46888, 41167, 26334]

totalGeral = numF2020, numM2020, numF2021, numM2021
plt.style.use('fivethirtyeight')

for index, value in enumerate(y):
  plt.text(value, index,str(value))

plt.barh(x, totalGeral, align='center', color=['red', 'white'], edgecolor='black', linewidth="1") 
plt.xlabel("Total participantes no ano")
plt.ylabel("Participantes por sexo")
# Out:
# Numero total de participantes do sexo feminino na planilha Microdados Enem 2020: 70044
# Numero total de participantes do sexo masculino planilha Microdados Enem 2020: 46888
#
# Numero total de participantes do sexo feminino planilha Microdados Enem 2021: 41167
# Numero total de participantes do sexo masculino planilha Microdados Enem 2021: 26334
# Text(0, 0.5, 'Participantes por sexo')
